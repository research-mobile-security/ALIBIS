# %% [markdown]
# # Generative AI - Vector Store

# %%
import os
from dotenv import load_dotenv
import openai
from langchain_openai import ChatOpenAI
# JSON loader
from langchain_community.document_loaders import JSONLoader
import json
from pathlib import Path
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import FAISS

# %% [markdown]
# # 1. Function

# %%
# Setup model
load_dotenv()
api_key = os.getenv('OPENAI_API_KEY')
openai.api_key = api_key
llm = ChatOpenAI(model="gpt-4-turbo",temperature=0)
# Function list all file in directory to list
def list_files_in_directory(directory_path):
    file_list = os.listdir(directory_path)
    file_list = [file for file in file_list if os.path.isfile(os.path.join(directory_path, file))]
    return file_list
# Function load JSON
def load_json_data(file_path,json_root):
    # Define the JSONLoader with the appropriate parameters
    loader = JSONLoader(
        file_path=file_path,
        jq_schema="."+json_root+"[]",
        text_content=False
    )
    # Load the JSON data
    data = loader.load()
    return data
# Function remove directory if exist
def remove_directory(directory_path):
    if os.path.exists(directory_path):
        try:
            os.rmdir(directory_path)
            print(f"Directory '{directory_path}' removed successfully.")
        except OSError as e:
            print(f"Error: {directory_path} : {e.strerror}")
    else:
        print(f"Directory '{directory_path}' does not exist.")
# Function-test write list to file 
def write_list_to_file(data_list, file_path):
    if os.path.exists(file_path):
        os.remove(file_path)
    with open(file_path, 'w') as file:
        for item in data_list:
            file.write(str(item) + '\n')

# %% [markdown]
# # 2. Static variable

# %%
declare_code_block_path = "./declare_code_block"
handle_code_block_path = "./handle_code_block"
exif_keyword_code_block_path = "./exif_keyword_code_block_re"

# %% [markdown]
# # 3. Main

# %%
# 1. Get file
declare_code_files = list_files_in_directory(declare_code_block_path)
handle_code_block_files = list_files_in_directory(handle_code_block_path)
exif_keyword_code_block_files = list_files_in_directory(exif_keyword_code_block_path)
# print("---------------------")
# print(declare_code_files)
# print("---------------------")
# print(handle_code_block_files)
# print("---------------------")
# print(exif_keyword_code_block_files)

# %%
# embedding
embeddings = OpenAIEmbeddings()
# documents
declare_code_documents_total = []
handle_code_documents_total = []
exif_keyword_code_documents_total = []

# %%
print("==============================DOCUMENT LOADER======================================")
for i in range(len(exif_keyword_code_block_files)):
    print("------------------------- Loop-"+str(i)+"-------------------------")
    exif_keyword_code_file = exif_keyword_code_block_path+"/"+exif_keyword_code_block_files[i]
    print("File :"+exif_keyword_code_file)
    exif_keyword_code_documents = load_json_data(exif_keyword_code_file,"exifkeyword")
    print("Length exif_keyword_code json_loader: "+str(len(exif_keyword_code_documents)))
    print(exif_keyword_code_documents)
    exif_keyword_code_documents_total.extend(exif_keyword_code_documents)
    # for document in declare_code_documents:
    #     print("**************")
    #     print(document)
    #break
print("*****************************************************************************")
print("Length exif_keyword_code json_loader total: "+str(len(exif_keyword_code_documents_total)))
print("*****************************************************************************")
write_list_to_file(exif_keyword_code_documents_total,"exif_keyword_code_documents_total.json")
# Out:
# ==============================DOCUMENT LOADER======================================
# ------------------------- Loop-0-------------------------
# File :./exif_keyword_code_block_re/Gallery-Photo-Vault-Album-1.0.3_exif_keyword.json
# Length exif_keyword_code json_loader: 69
# [Document(page_content='if ((("Make".equals(e.b) || "Model".equals(e.b)) && value.i(this.g).contains("PENTAX")) || ("Compression".equals(e.b) && value.h(this.g) == 65535)) {', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Gallery-Photo-Vault-Album-1.0.3_exif_keyword.json', 'seq_num': 1}), Document(page_content='final e e89 = new e("GPSTrackRef", 14, 2);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Gallery-Photo-Vault-Album-1.0.3_exif_keyword.json', 'seq_num': 2}), Document(page_content='final e e99 = new e("GPSDestBearing", 24, 5);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Gallery-Photo-Vault-Album-1.0.3_exif_keyword.json', 'seq_num': 3}), Document(page_content='final e e103 = new e("GPSAreaInformation", 28, 7);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Gallery-Photo-Vault-Album-1.0.3_exif_keyword.json', 'seq_num': 4}), Document(page_content='if (f != null && this.f("DateTime") == null) {', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Gallery-Photo-Vault-Album-1.0.3_exif_keyword.json', 'seq_num': 5}), Document(page_content='final e e128 = new e("Software", 305, 2);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Gallery-Photo-Vault-Album-1.0.3_exif_keyword.json', 'seq_num': 6}), Document(page_content='final e e95 = new e("GPSDestLatitude", 20, 5);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Gallery-Photo-Vault-Album-1.0.3_exif_keyword.json', 'seq_num': 7}), Document(page_content='final e e32 = new e("MakerNote", 37500, 7);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Gallery-Photo-Vault-Album-1.0.3_exif_keyword.json', 'seq_num': 8}), Document(page_content='final e e104 = new e("GPSDateStamp", 29, 2);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Gallery-Photo-Vault-Album-1.0.3_exif_keyword.json', 'seq_num': 9}), Document(page_content='final e e116 = new e("Make", 271, 2);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Gallery-Photo-Vault-Album-1.0.3_exif_keyword.json', 'seq_num': 10}), Document(page_content='final e e82 = new e("GPSTimeStamp", 7, 5);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Gallery-Photo-Vault-Album-1.0.3_exif_keyword.json', 'seq_num': 11}), Document(page_content='final d d = this.e[1].get("MakerNote");', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Gallery-Photo-Vault-Album-1.0.3_exif_keyword.json', 'seq_num': 12}), Document(page_content='final String f = this.f("DateTimeOriginal");', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Gallery-Photo-Vault-Album-1.0.3_exif_keyword.json', 'seq_num': 13}), Document(page_content='final e e91 = new e("GPSImgDirectionRef", 16, 2);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Gallery-Photo-Vault-Album-1.0.3_exif_keyword.json', 'seq_num': 14}), Document(page_content='final e e14 = new e("DateTimeOriginal", 36867, 2);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Gallery-Photo-Vault-Album-1.0.3_exif_keyword.json', 'seq_num': 15}), Document(page_content='final e e70 = new e("LensMake", 42035, 2);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Gallery-Photo-Vault-Album-1.0.3_exif_keyword.json', 'seq_num': 16}), Document(page_content='final e e11 = new e("ISOSpeedLatitudeyyy", 34868, 4);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Gallery-Photo-Vault-Album-1.0.3_exif_keyword.json', 'seq_num': 17}), Document(page_content='final e e71 = new e("LensModel", 42036, 2);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Gall ...
# ------------------------- Loop-1-------------------------
# File :./exif_keyword_code_block_re/Gallery-Album-Photo-Vault-1.4.5_exif_keyword.json
# Length exif_keyword_code json_loader: 54
# [Document(page_content='final d d11 = new d("ISOSpeedLatitudeyyy", 34868, 4);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Gallery-Album-Photo-Vault-1.4.5_exif_keyword.json', 'seq_num': 1}), Document(page_content='final d d93 = new d("GPSMapDatum", 18, 2);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Gallery-Album-Photo-Vault-1.4.5_exif_keyword.json', 'seq_num': 2}), Document(page_content='final d d128 = new d("Software", 305, 2);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Gallery-Album-Photo-Vault-1.4.5_exif_keyword.json', 'seq_num': 3}), Document(page_content='final d d87 = new d("GPSSpeedRef", 12, 2);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Gallery-Album-Photo-Vault-1.4.5_exif_keyword.json', 'seq_num': 4}), Document(page_content='final d d97 = new d("GPSDestLongitude", 22, 5);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Gallery-Album-Photo-Vault-1.4.5_exif_keyword.json', 'seq_num': 5}), Document(page_content='final d d94 = new d("GPSDestLatitudeRef", 19, 2);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Gallery-Album-Photo-Vault-1.4.5_exif_keyword.json', 'seq_num': 6}), Document(page_content='final d d103 = new d("GPSAreaInformation", 28, 7);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Gallery-Album-Photo-Vault-1.4.5_exif_keyword.json', 'seq_num': 7}), Document(page_content='if (string.equals("GPSTimeStamp")) {', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Gallery-Album-Photo-Vault-1.4.5_exif_keyword.json', 'seq_num': 8}), Document(page_content='final d d96 = new d("GPSDestLongitudeRef", 21, 2);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Gallery-Album-Photo-Vault-1.4.5_exif_keyword.json', 'seq_num': 9}), Document(page_content='N = new HashSet<String>(Arrays.asList("FNumber", "DigitalZoomRatio", "ExposureTime", "SubjectDistance", "GPSTimeStamp"));', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Gallery-Album-Photo-Vault-1.4.5_exif_keyword.json', 'seq_num': 10}), Document(page_content='final d d92 = new d("GPSImgDirection", 17, 5);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Gallery-Album-Photo-Vault-1.4.5_exif_keyword.json', 'seq_num': 11}), Document(page_content='final d d101 = new d("GPSDestDistance", 26, 5);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Gallery-Album-Photo-Vault-1.4.5_exif_keyword.json', 'seq_num': 12}), Document(page_content='final d d89 = new d("GPSTrackRef", 14, 2);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Gallery-Album-Photo-Vault-1.4.5_exif_keyword.json', 'seq_num': 13}), Document(page_content='final d d79 = new d("GPSLongitude", 4, 5);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Gallery-Album-Photo-Vault-1.4.5_exif_keyword.json', 'seq_num': 14}), Document(page_content='final d d86 = new d("GPSDOP", 11, 5);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Gallery-Album-Photo-Vault-1.4.5_exif_keyword.json', 'seq_num': 15}), Document(page_content='final d d70 = new d("LensMake", 42035, 2);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Gallery-Album-Photo-Vault-1.4.5_exif_keyword.json', 'seq_num': 16}), Document(page_content='final d d116 = new d("Make", 271, 2);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Gallery-Album-Photo-Vault-1.4.5_exif_keyword.json', 'seq_num': 17}), Document(page_content='final d d129 = new d("DateTime", 306, 2);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Gallery-Album-Photo-Vault-1.4.5_exif_keyword ...
# ------------------------- Loop-2-------------------------
# File :./exif_keyword_code_block_re/My-Camera-0.1_exif_keyword.json
# Length exif_keyword_code json_loader: 0
# []
# ------------------------- Loop-3-------------------------
# File :./exif_keyword_code_block_re/SquareIt-0.7.3_exif_keyword.json
# Length exif_keyword_code json_loader: 53
# [Document(page_content='((ImageView)this.this$0.$a().findViewById(2131165237)).setImageBitmap(this.this$0.model.newBitmap);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/SquareIt-0.7.3_exif_keyword.json', 'seq_num': 1}), Document(page_content='this.this$0.model.bitmap = this.this$0.decodeFile(file, bitmapInfo);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/SquareIt-0.7.3_exif_keyword.json', 'seq_num': 2}), Document(page_content='PreviewModel model;', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/SquareIt-0.7.3_exif_keyword.json', 'seq_num': 3}), Document(page_content='this.this$1.this$0.model.bitmap.recycle();', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/SquareIt-0.7.3_exif_keyword.json', 'seq_num': 4}), Document(page_content='this.this$0.model.fileName = file.getName();', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/SquareIt-0.7.3_exif_keyword.json', 'seq_num': 5}), Document(page_content='this.model = new PreviewModel();', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/SquareIt-0.7.3_exif_keyword.json', 'seq_num': 6}), Document(page_content='this.model.color = PreferenceManager.getDefaultSharedPreferences((Context)this).getInt("swatch", -1);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/SquareIt-0.7.3_exif_keyword.json', 'seq_num': 7}), Document(page_content='if (this.model.orientation != 0) {', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/SquareIt-0.7.3_exif_keyword.json', 'seq_num': 8}), Document(page_content='if (this.model == null) {', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/SquareIt-0.7.3_exif_keyword.json', 'seq_num': 9}), Document(page_content='this.this$0.model.orientation = 0;', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/SquareIt-0.7.3_exif_keyword.json', 'seq_num': 10}), Document(page_content='this.model.newBitmap = Bitmap.createBitmap(n3, n3, Bitmap$Config.ARGB_8888);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/SquareIt-0.7.3_exif_keyword.json', 'seq_num': 11}), Document(page_content='this.model.orientation = realPathFromURI.Orientation;', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/SquareIt-0.7.3_exif_keyword.json', 'seq_num': 12}), Document(page_content='this.this$0.model.bitmap.recycle();', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/SquareIt-0.7.3_exif_keyword.json', 'seq_num': 13}), Document(page_content='menu.add("Instagram").setIcon(this.this$0.$a().model.itgIcon).setShowAsAction(2);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/SquareIt-0.7.3_exif_keyword.json', 'seq_num': 14}), Document(page_content='this.model.originalFilePath = originalFilePath;', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/SquareIt-0.7.3_exif_keyword.json', 'seq_num': 15}), Document(page_content='(this.pw = new ChooseColorPopupWindow(inflate, Units.toPx(300, density), Units.toPx(180, density), true, this.model.color)).setOutsideTouchable(true);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/SquareIt-0.7.3_exif_keyword.json', 'seq_num': 16}), Document(page_content='((ImageView)this.$a().findViewById(2131165237)).setImageBitmap(this.model.newBitmap);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/SquareIt-0.7.3_exif_keyword.json', 'seq_num': 17}), Document(page_content='this.this$0.model.color = this.this$0.pw.getColor();', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/SquareIt-0.7.3_exif_keyword.json', 'seq_num': 18}), Document(page_content='matrix.postRotate((float)this.model.orientatio ...
# ------------------------- Loop-4-------------------------
# File :./exif_keyword_code_block_re/ASTRO-8.12.0_exif_keyword.json
# Length exif_keyword_code json_loader: 21
# [Document(page_content='if (string.equals("GPSTimeStamp")) {', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/ASTRO-8.12.0_exif_keyword.json', 'seq_num': 1}), Document(page_content='if (e != null && this.e("DateTime") == null) {', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/ASTRO-8.12.0_exif_keyword.json', 'seq_num': 2}), Document(page_content='this.e("http://ns.adobe.com/tiff/1.0/", "Software", "http://ns.adobe.com/xap/1.0/", "CreatorTool", null);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/ASTRO-8.12.0_exif_keyword.json', 'seq_num': 3}), Document(page_content='x15 = y14.e(x14, "exif:DateTimeDigitized", false);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/ASTRO-8.12.0_exif_keyword.json', 'seq_num': 4}), Document(page_content='this.e("http://ns.adobe.com/tiff/1.0/", "DateTime", "http://ns.adobe.com/xap/1.0/", "ModifyDate", null);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/ASTRO-8.12.0_exif_keyword.json', 'seq_num': 5}), Document(page_content='final d[] array = a0 = new d[] { new d("NewSubfileType", 254, 4), new d("SubfileType", 255, 4), new d("ImageWidth", 256, 3, 4), new d("ImageLength", 257, 3, 4), new d("BitsPerSample", 258, 3), new d("Compression", 259, 3), new d("PhotometricInterpretation", 262, 3), new d("ImageDescription", 270, 2), new d("Make", 271, 2), new d("Model", 272, 2), new d("StripOffsets", 273, 3, 4), new d("Orientation", 274, 3), new d("SamplesPerPixel", 277, 3), new d("RowsPerStrip", 278, 3, 4), new d("StripByteCounts", 279, 3, 4), new d("XResolution", 282, 5), new d("YResolution", 283, 5), new d("PlanarConfiguration", 284, 3), new d("ResolutionUnit", 296, 3), new d("TransferFunction", 301, 3), new d("Software", 305, 2), new d("DateTime", 306, 2), new d("Artist", 315, 2), new d("WhitePoint", 318, 5), new d("PrimaryChromaticities", 319, 5), new d("SubIFDPointer", 330, 4), new d("JPEGInterchangeFormat", 513, 4), new d("JPEGInterchangeFormatLength", 514, 4), new d("YCbCrCoefficients", 529, 5), new d("YCbCrSubSampling", 530, 3), new d("YCbCrPositioning", 531, 3), new d("ReferenceBlackWhite", 532, 5), new d("Copyright", 33432, 2), new d("ExifIFDPointer", 34665, 4), new d("GPSInfoIFDPointer", 34853, 4), new d("SensorTopBorder", 4, 4), new d("SensorLeftBorder", 5, 4), new d("SensorBottomBorder", 6, 4), new d("SensorRightBorder", 7, 4), new d("ISO", 23, 3), new d("JpgFromRaw", 46, 7), new d("Xmp", 700, 1) };', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/ASTRO-8.12.0_exif_keyword.json', 'seq_num': 6}), Document(page_content='final d[] array3 = c0 = new d[] { new d("GPSVersionID", 0, 1), new d("GPSLatitudeRef", 1, 2), new d("GPSLatitude", 2, 5), new d("GPSLongitudeRef", 3, 2), new d("GPSLongitude", 4, 5), new d("GPSAltitudeRef", 5, 1), new d("GPSAltitude", 6, 5), new d("GPSTimeStamp", 7, 5), new d("GPSSatellites", 8, 2), new d("GPSStatus", 9, 2), new d("GPSMeasureMode", 10, 2), new d("GPSDOP", 11, 5), new d("GPSSpeedRef", 12, 2), new d("GPSSpeed", 13, 5), new d("GPSTrackRef", 14, 2), new d("GPSTrack", 15, 5), new d("GPSImgDirectionRef", 16, 2), new d("GPSImgDirection", 17, 5), new d("GPSMapDatum", 18, 2), new d("GPSDestLatitudeRef", 19, 2), new d("GPSDestLatitude", 20, 5), new d("GPSDestLongitudeRef", 21, 2), new d("GPSDestLongitude", 22, 5), new d("GPSDestBearingRef", 23, 2), new d("GPSDestBearing", 24, 5), new d("GPSDestDistanceRef", 25, 2), new d("GPSDestDistance", 26, 5), new d("GPSProcessingMethod", 27, 7), new d("GPSAreaInformation", 28, 7), new d("GPSDateStamp", 29, 2), new d("GPSDifferential", 30, 3), new d("GPSHPositioningError", 31, 5) };', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/ASTRO-8.12.0_exif_keyword.json', 'seq_num': 7}), Document(page_content='if ((("Make".equals(d.b) || "Model".equals(d.b)) && value.j(this.h).contains("PENTAX")) || ("Compr ...
# ------------------------- Loop-5-------------------------
# File :./exif_keyword_code_block_re/HD-Camera-1.66_exif_keyword.json
# Length exif_keyword_code json_loader: 25
# [Document(page_content='this.g0[0].put("DateTime", c.e.a.a.d.e(d));', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/HD-Camera-1.66_exif_keyword.json', 'seq_num': 1}), Document(page_content='final e[] array = E = new e[] { new e("NewSubfileType", 254, 4), new e("SubfileType", 255, 4), new e("ImageWidth", 256, 3, 4), new e("ImageLength", 257, 3, 4), new e("BitsPerSample", 258, 3), new e("Compression", 259, 3), new e("PhotometricInterpretation", 262, 3), new e("ImageDescription", 270, 2), new e("Make", 271, 2), new e("Model", 272, 2), new e("StripOffsets", 273, 3, 4), new e("Orientation", 274, 3), new e("SamplesPerPixel", 277, 3), new e("RowsPerStrip", 278, 3, 4), new e("StripByteCounts", 279, 3, 4), new e("XResolution", 282, 5), new e("YResolution", 283, 5), new e("PlanarConfiguration", 284, 3), new e("ResolutionUnit", 296, 3), new e("TransferFunction", 301, 3), new e("Software", 305, 2), new e("DateTime", 306, 2), new e("Artist", 315, 2), new e("WhitePoint", 318, 5), new e("PrimaryChromaticities", 319, 5), new e("SubIFDPointer", 330, 4), new e("JPEGInterchangeFormat", 513, 4), new e("JPEGInterchangeFormatLength", 514, 4), new e("YCbCrCoefficients", 529, 5), new e("YCbCrSubSampling", 530, 3), new e("YCbCrPositioning", 531, 3), new e("ReferenceBlackWhite", 532, 5), new e("Copyright", 33432, 2), new e("ExifIFDPointer", 34665, 4), new e("GPSInfoIFDPointer", 34853, 4), new e("SensorTopBorder", 4, 4), new e("SensorLeftBorder", 5, 4), new e("SensorBottomBorder", 6, 4), new e("SensorRightBorder", 7, 4), new e("ISO", 23, 3), new e("JpgFromRaw", 46, 7), new e("Xmp", 700, 1) };', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/HD-Camera-1.66_exif_keyword.json', 'seq_num': 2}), Document(page_content='if (key.equals("GPSTimeStamp")) {', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/HD-Camera-1.66_exif_keyword.json', 'seq_num': 3}), Document(page_content='Toast.makeText(this.b.getApplicationContext(), 2131624765, 0).show();', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/HD-Camera-1.66_exif_keyword.json', 'seq_num': 4}), Document(page_content='S = new HashSet<String>(Arrays.asList("FNumber", "DigitalZoomRatio", "ExposureTime", "SubjectDistance", "GPSTimeStamp"));', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/HD-Camera-1.66_exif_keyword.json', 'seq_num': 5}), Document(page_content='return this.r.getString("preference_stamp_gpsformat", "preference_stamp_gpsformat_default");', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/HD-Camera-1.66_exif_keyword.json', 'seq_num': 6}), Document(page_content='Toast.makeText((Context)mainActivity, 2131624249, 0).show();', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/HD-Camera-1.66_exif_keyword.json', 'seq_num': 7}), Document(page_content='case "preference_stamp_gpsformat": {', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/HD-Camera-1.66_exif_keyword.json', 'seq_num': 8}), Document(page_content='final e[] array5 = I = new e[] { new e("NewSubfileType", 254, 4), new e("SubfileType", 255, 4), new e("ThumbnailImageWidth", 256, 3, 4), new e("ThumbnailImageLength", 257, 3, 4), new e("BitsPerSample", 258, 3), new e("Compression", 259, 3), new e("PhotometricInterpretation", 262, 3), new e("ImageDescription", 270, 2), new e("Make", 271, 2), new e("Model", 272, 2), new e("StripOffsets", 273, 3, 4), new e("ThumbnailOrientation", 274, 3), new e("SamplesPerPixel", 277, 3), new e("RowsPerStrip", 278, 3, 4), new e("StripByteCounts", 279, 3, 4), new e("XResolution", 282, 5), new e("YResolution", 283, 5), new e("PlanarConfiguration", 284, 3), new e("ResolutionUnit", 296, 3), new e("TransferFunction", 301, 3), new e("Software", 305, 2), new e("DateTime", 306, 2), new e("Artist", 315, 2), new e("WhitePoint", 318, 5), new e("PrimaryChromaticities", 319, 5 ...
# ------------------------- Loop-6-------------------------
# File :./exif_keyword_code_block_re/Calculator-Lock-Photo-Video-locker-Safe-Browser-1.0_exif_keyword.json
# Length exif_keyword_code json_loader: 13
# [Document(page_content='x = new c[] { new c("GPSVersionID", 0, 1), new c("GPSLatitudeRef", 1, 2), new c("GPSLatitude", 2, 5), new c("GPSLongitudeRef", 3, 2), new c("GPSLongitude", 4, 5), new c("GPSAltitudeRef", 5, 1), new c("GPSAltitude", 6, 5), new c("GPSTimeStamp", 7, 5), new c("GPSSatellites", 8, 2), new c("GPSStatus", 9, 2), new c("GPSMeasureMode", 10, 2), new c("GPSDOP", 11, 5), new c("GPSSpeedRef", 12, 2), new c("GPSSpeed", 13, 5), new c("GPSTrackRef", 14, 2), new c("GPSTrack", 15, 5), new c("GPSImgDirectionRef", 16, 2), new c("GPSImgDirection", 17, 5), new c("GPSMapDatum", 18, 2), new c("GPSDestLatitudeRef", 19, 2), new c("GPSDestLatitude", 20, 5), new c("GPSDestLongitudeRef", 21, 2), new c("GPSDestLongitude", 22, 5), new c("GPSDestBearingRef", 23, 2), new c("GPSDestBearing", 24, 5), new c("GPSDestDistanceRef", 25, 2), new c("GPSDestDistance", 26, 5), new c("GPSProcessingMethod", 27, 7), new c("GPSAreaInformation", 28, 7), new c("GPSDateStamp", 29, 2), new c("GPSDifferential", 30, 3) };', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Calculator-Lock-Photo-Video-locker-Safe-Browser-1.0_exif_keyword.json', 'seq_num': 1}), Document(page_content='this.d[0].put("DateTime", vb.b.a(c));', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Calculator-Lock-Photo-Video-locker-Safe-Browser-1.0_exif_keyword.json', 'seq_num': 2}), Document(page_content='if ("MakerNote".equals(c.b)) {', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Calculator-Lock-Photo-Video-locker-Safe-Browser-1.0_exif_keyword.json', 'seq_num': 3}), Document(page_content='J = new HashSet<String>(Arrays.asList("FNumber", "DigitalZoomRatio", "ExposureTime", "SubjectDistance", "GPSTimeStamp"));', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Calculator-Lock-Photo-Video-locker-Safe-Browser-1.0_exif_keyword.json', 'seq_num': 4}), Document(page_content='if ((("Make".equals(c.b) || "Model".equals(c.b)) && value.g(this.f).contains("PENTAX")) || ("Compression".equals(c.b) && value.f(this.f) == 65535)) {', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Calculator-Lock-Photo-Video-locker-Safe-Browser-1.0_exif_keyword.json', 'seq_num': 5}), Document(page_content='G = new c[] { new c("SubIFDPointer", 330, 4), new c("ExifIFDPointer", 34665, 4), new c("GPSInfoIFDPointer", 34853, 4), new c("InteroperabilityIFDPointer", 40965, 4), new c("CameraSettingsIFDPointer", 8224, 1), new c("ImageProcessingIFDPointer", 8256, 1) };', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Calculator-Lock-Photo-Video-locker-Safe-Browser-1.0_exif_keyword.json', 'seq_num': 6}), Document(page_content='z = new c[] { new c("NewSubfileType", 254, 4), new c("SubfileType", 255, 4), new c("ThumbnailImageWidth", 256, 3, 4), new c("ThumbnailImageLength", 257, 3, 4), new c("BitsPerSample", 258, 3), new c("Compression", 259, 3), new c("PhotometricInterpretation", 262, 3), new c("ImageDescription", 270, 2), new c("Make", 271, 2), new c("Model", 272, 2), new c("StripOffsets", 273, 3, 4), new c("Orientation", 274, 3), new c("SamplesPerPixel", 277, 3), new c("RowsPerStrip", 278, 3, 4), new c("StripByteCounts", 279, 3, 4), new c("XResolution", 282, 5), new c("YResolution", 283, 5), new c("PlanarConfiguration", 284, 3), new c("ResolutionUnit", 296, 3), new c("TransferFunction", 301, 3), new c("Software", 305, 2), new c("DateTime", 306, 2), new c("Artist", 315, 2), new c("WhitePoint", 318, 5), new c("PrimaryChromaticities", 319, 5), new c("SubIFDPointer", 330, 4), new c("JPEGInterchangeFormat", 513, 4), new c("JPEGInterchangeFormatLength", 514, 4), new c("YCbCrCoefficients", 529, 5), new c("YCbCrSubSampling", 530, 3), new c("YCbCrPositioning", 531, 3), new c("ReferenceBlackWhite", 532, 5), new c("Copyright", 33432, 2), new c("ExifIFDPointer", 34665, 4), new c("GPSInfoIFDPointer", 34853, 4), new c("DNGVersion", 50706, 1), ne ...
# ------------------------- Loop-7-------------------------
# File :./exif_keyword_code_block_re/Camera-Roll-Gallery-v1.0.6_exif_keyword.json
# Length exif_keyword_code json_loader: 16
# [Document(page_content='q = new d[] { new d("GPSVersionID", 0, 1), new d("GPSLatitudeRef", 1, 2), new d("GPSLatitude", 2, 5), new d("GPSLongitudeRef", 3, 2), new d("GPSLongitude", 4, 5), new d("GPSAltitudeRef", 5, 1), new d("GPSAltitude", 6, 5), new d("GPSTimeStamp", 7, 5), new d("GPSSatellites", 8, 2), new d("GPSStatus", 9, 2), new d("GPSMeasureMode", 10, 2), new d("GPSDOP", 11, 5), new d("GPSSpeedRef", 12, 2), new d("GPSSpeed", 13, 5), new d("GPSTrackRef", 14, 2), new d("GPSTrack", 15, 5), new d("GPSImgDirectionRef", 16, 2), new d("GPSImgDirection", 17, 5), new d("GPSMapDatum", 18, 2), new d("GPSDestLatitudeRef", 19, 2), new d("GPSDestLatitude", 20, 5), new d("GPSDestLongitudeRef", 21, 2), new d("GPSDestLongitude", 22, 5), new d("GPSDestBearingRef", 23, 2), new d("GPSDestBearing", 24, 5), new d("GPSDestDistanceRef", 25, 2), new d("GPSDestDistance", 26, 5), new d("GPSProcessingMethod", 27, 7), new d("GPSAreaInformation", 28, 7), new d("GPSDateStamp", 29, 2), new d("GPSDifferential", 30, 3) };', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Camera-Roll-Gallery-v1.0.6_exif_keyword.json', 'seq_num': 1}), Document(page_content='final c c = this.J[1].get("MakerNote");', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Camera-Roll-Gallery-v1.0.6_exif_keyword.json', 'seq_num': 2}), Document(page_content='y = new d[] { new d("SubIFDPointer", 330, 4), new d("ExifIFDPointer", 34665, 4), new d("GPSInfoIFDPointer", 34853, 4), new d("InteroperabilityIFDPointer", 40965, 4), new d("CameraSettingsIFDPointer", 8224, 1), new d("ImageProcessingIFDPointer", 8256, 1) };', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Camera-Roll-Gallery-v1.0.6_exif_keyword.json', 'seq_num': 3}), Document(page_content='final String a = this.a("DateTimeOriginal");', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Camera-Roll-Gallery-v1.0.6_exif_keyword.json', 'seq_num': 4}), Document(page_content='this.J[0].put("DateTime", android.support.d.a.c.b(a));', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Camera-Roll-Gallery-v1.0.6_exif_keyword.json', 'seq_num': 5}), Document(page_content='p = new d[] { new d("ExposureTime", 33434, 5), new d("FNumber", 33437, 5), new d("ExposureProgram", 34850, 3), new d("SpectralSensitivity", 34852, 2), new d("PhotographicSensitivity", 34855, 3), new d("OECF", 34856, 7), new d("ExifVersion", 36864, 2), new d("DateTimeOriginal", 36867, 2), new d("DateTimeDigitized", 36868, 2), new d("ComponentsConfiguration", 37121, 7), new d("CompressedBitsPerPixel", 37122, 5), new d("ShutterSpeedValue", 37377, 10), new d("ApertureValue", 37378, 5), new d("BrightnessValue", 37379, 10), new d("ExposureBiasValue", 37380, 10), new d("MaxApertureValue", 37381, 5), new d("SubjectDistance", 37382, 5), new d("MeteringMode", 37383, 3), new d("LightSource", 37384, 3), new d("Flash", 37385, 3), new d("FocalLength", 37386, 5), new d("SubjectArea", 37396, 3), new d("MakerNote", 37500, 7), new d("UserComment", 37510, 7), new d("SubSecTime", 37520, 2), new d("SubSecTimeOriginal", 37521, 2), new d("SubSecTimeDigitized", 37522, 2), new d("FlashpixVersion", 40960, 7), new d("ColorSpace", 40961, 3), new d("PixelXDimension", 40962, 3, 4), new d("PixelYDimension", 40963, 3, 4), new d("RelatedSoundFile", 40964, 2), new d("InteroperabilityIFDPointer", 40965, 4), new d("FlashEnergy", 41483, 5), new d("SpatialFrequencyResponse", 41484, 7), new d("FocalPlaneXResolution", 41486, 5), new d("FocalPlaneYResolution", 41487, 5), new d("FocalPlaneResolutionUnit", 41488, 3), new d("SubjectLocation", 41492, 3), new d("ExposureIndex", 41493, 5), new d("SensingMethod", 41495, 3), new d("FileSource", 41728, 7), new d("SceneType", 41729, 7), new d("CFAPattern", 41730, 7), new d("CustomRendered", 41985, 3), new d("ExposureMode", 41986, 3), new d("WhiteBalance", 41987, 3), new d("DigitalZoomRatio", 41988, 5), new d("FocalLengt ...
# ------------------------- Loop-8-------------------------
# File :./exif_keyword_code_block_re/Photo-Video-Locker-Calculator-23.0_exif_keyword.json
# Length exif_keyword_code json_loader: 18
# [Document(page_content='final String d = this.d("DateTimeOriginal");', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Photo-Video-Locker-Calculator-23.0_exif_keyword.json', 'seq_num': 1}), Document(page_content='b0 = new HashSet<String>(Arrays.asList("FNumber", "DigitalZoomRatio", "ExposureTime", "SubjectDistance", "GPSTimeStamp"));', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Photo-Video-Locker-Calculator-23.0_exif_keyword.json', 'seq_num': 2}), Document(page_content='final d[] array3 = P = new d[] { new d("GPSVersionID", 0, 1), new d("GPSLatitudeRef", 1, 2), new d("GPSLatitude", 2, 5), new d("GPSLongitudeRef", 3, 2), new d("GPSLongitude", 4, 5), new d("GPSAltitudeRef", 5, 1), new d("GPSAltitude", 6, 5), new d("GPSTimeStamp", 7, 5), new d("GPSSatellites", 8, 2), new d("GPSStatus", 9, 2), new d("GPSMeasureMode", 10, 2), new d("GPSDOP", 11, 5), new d("GPSSpeedRef", 12, 2), new d("GPSSpeed", 13, 5), new d("GPSTrackRef", 14, 2), new d("GPSTrack", 15, 5), new d("GPSImgDirectionRef", 16, 2), new d("GPSImgDirection", 17, 5), new d("GPSMapDatum", 18, 2), new d("GPSDestLatitudeRef", 19, 2), new d("GPSDestLatitude", 20, 5), new d("GPSDestLongitudeRef", 21, 2), new d("GPSDestLongitude", 22, 5), new d("GPSDestBearingRef", 23, 2), new d("GPSDestBearing", 24, 5), new d("GPSDestDistanceRef", 25, 2), new d("GPSDestDistance", 26, 5), new d("GPSProcessingMethod", 27, 7), new d("GPSAreaInformation", 28, 7), new d("GPSDateStamp", 29, 2), new d("GPSDifferential", 30, 3), new d("GPSHPositioningError", 31, 5) };', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Photo-Video-Locker-Calculator-23.0_exif_keyword.json', 'seq_num': 3}), Document(page_content='if (o.equals("GPSTimeStamp")) {', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Photo-Video-Locker-Calculator-23.0_exif_keyword.json', 'seq_num': 4}), Document(page_content='final d[] array = N = new d[] { new d("NewSubfileType", 254, 4), new d("SubfileType", 255, 4), new d("ImageWidth", 256, 3, 4), new d("ImageLength", 257, 3, 4), new d("BitsPerSample", 258, 3), new d("Compression", 259, 3), new d("PhotometricInterpretation", 262, 3), new d("ImageDescription", 270, 2), new d("Make", 271, 2), new d("Model", 272, 2), new d("StripOffsets", 273, 3, 4), new d("Orientation", 274, 3), new d("SamplesPerPixel", 277, 3), new d("RowsPerStrip", 278, 3, 4), new d("StripByteCounts", 279, 3, 4), new d("XResolution", 282, 5), new d("YResolution", 283, 5), new d("PlanarConfiguration", 284, 3), new d("ResolutionUnit", 296, 3), new d("TransferFunction", 301, 3), new d("Software", 305, 2), new d("DateTime", 306, 2), new d("Artist", 315, 2), new d("WhitePoint", 318, 5), new d("PrimaryChromaticities", 319, 5), new d("SubIFDPointer", 330, 4), new d("JPEGInterchangeFormat", 513, 4), new d("JPEGInterchangeFormatLength", 514, 4), new d("YCbCrCoefficients", 529, 5), new d("YCbCrSubSampling", 530, 3), new d("YCbCrPositioning", 531, 3), new d("ReferenceBlackWhite", 532, 5), new d("Copyright", 33432, 2), new d("ExifIFDPointer", 34665, 4), new d("GPSInfoIFDPointer", 34853, 4), new d("SensorTopBorder", 4, 4), new d("SensorLeftBorder", 5, 4), new d("SensorBottomBorder", 6, 4), new d("SensorRightBorder", 7, 4), new d("ISO", 23, 3), new d("JpgFromRaw", 46, 7), new d("Xmp", 700, 1) };', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Photo-Video-Locker-Calculator-23.0_exif_keyword.json', 'seq_num': 5}), Document(page_content='final c c = this.f[1].get("MakerNote");', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Photo-Video-Locker-Calculator-23.0_exif_keyword.json', 'seq_num': 6}), Document(page_content='final d[] array2 = O = new d[] { new d("ExposureTime", 33434, 5), new d("FNumber", 33437, 5), new d("ExposureProgram", 34850, 3), new d("SpectralSensitivity", 34852, 2), new d("PhotographicSensitivity", 34855, 3), new d("OECF", 3 ...
# ------------------------- Loop-9-------------------------
# File :./exif_keyword_code_block_re/X-plore-4.31.03_exif_keyword.json
# Length exif_keyword_code json_loader: 24
# [Document(page_content='final e e = this.j[1].get("MakerNote");', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/X-plore-4.31.03_exif_keyword.json', 'seq_num': 1}), Document(page_content='if ("MakerNote".equals(g.a)) {', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/X-plore-4.31.03_exif_keyword.json', 'seq_num': 2}), Document(page_content='return M(this.g("DateTimeOriginal"), this.g("SubSecTimeOriginal"));', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/X-plore-4.31.03_exif_keyword.json', 'seq_num': 3}), Document(page_content='if (string.equals("GPSTimeStamp")) {', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/X-plore-4.31.03_exif_keyword.json', 'seq_num': 4}), Document(page_content='final String g3 = this.g("GPSLongitude");', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/X-plore-4.31.03_exif_keyword.json', 'seq_num': 5}), Document(page_content='final String g = this.g("GPSDateStamp");', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/X-plore-4.31.03_exif_keyword.json', 'seq_num': 6}), Document(page_content='sb.append("Latitude/longitude values are not parsable. ");', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/X-plore-4.31.03_exif_keyword.json', 'seq_num': 7}), Document(page_content='final String g4 = this.g("GPSLongitudeRef");', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/X-plore-4.31.03_exif_keyword.json', 'seq_num': 8}), Document(page_content='final g[] array3 = F = new g[] { new g("GPSVersionID", 0, 1), new g("GPSLatitudeRef", 1, 2), new g("GPSLatitude", 2, 5), new g("GPSLongitudeRef", 3, 2), new g("GPSLongitude", 4, 5), new g("GPSAltitudeRef", 5, 1), new g("GPSAltitude", 6, 5), new g("GPSTimeStamp", 7, 5), new g("GPSSatellites", 8, 2), new g("GPSStatus", 9, 2), new g("GPSMeasureMode", 10, 2), new g("GPSDOP", 11, 5), new g("GPSSpeedRef", 12, 2), new g("GPSSpeed", 13, 5), new g("GPSTrackRef", 14, 2), new g("GPSTrack", 15, 5), new g("GPSImgDirectionRef", 16, 2), new g("GPSImgDirection", 17, 5), new g("GPSMapDatum", 18, 2), new g("GPSDestLatitudeRef", 19, 2), new g("GPSDestLatitude", 20, 5), new g("GPSDestLongitudeRef", 21, 2), new g("GPSDestLongitude", 22, 5), new g("GPSDestBearingRef", 23, 2), new g("GPSDestBearing", 24, 5), new g("GPSDestDistanceRef", 25, 2), new g("GPSDestDistance", 26, 5), new g("GPSProcessingMethod", 27, 7), new g("GPSAreaInformation", 28, 7), new g("GPSDateStamp", 29, 2), new g("GPSDifferential", 30, 3), new g("GPSHPositioningError", 31, 5) };', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/X-plore-4.31.03_exif_keyword.json', 'seq_num': 9}), Document(page_content='sb.append("GPS Timestamp format is not rational. format=");', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/X-plore-4.31.03_exif_keyword.json', 'seq_num': 10}), Document(page_content='return M(this.g("DateTime"), this.g("SubSecTime"));', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/X-plore-4.31.03_exif_keyword.json', 'seq_num': 11}), Document(page_content='final String g = this.g("DateTimeOriginal");', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/X-plore-4.31.03_exif_keyword.json', 'seq_num': 12}), Document(page_content='sb2.append("Invalid GPS Timestamp array. array=");', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/X-plore-4.31.03_exif_keyword.json', 'seq_num': 13}), Document(page_content='final String g2 = this.g("GPSLatitudeRef");', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/X-plore-4.31.03_exif_keyword.json', 'seq_num': 14}), Document(page_content='R = new HashSet(Arrays.asList("FNumber", "DigitalZoomRatio", "ExposureTime", "SubjectDistance", "GPSTi ...
# ------------------------- Loop-10-------------------------
# File :./exif_keyword_code_block_re/Camera-for-OPPO-HD-Camera-1.2_exif_keyword.json
# Length exif_keyword_code json_loader: 59
# [Document(page_content='final d d11 = new d("ISOSpeedLatitudeyyy", 34868, 4);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Camera-for-OPPO-HD-Camera-1.2_exif_keyword.json', 'seq_num': 1}), Document(page_content='J = new d[] { new d("SubIFDPointer", 330, 4), new d("ExifIFDPointer", 34665, 4), new d("GPSInfoIFDPointer", 34853, 4), new d("InteroperabilityIFDPointer", 40965, 4), new d("CameraSettingsIFDPointer", 8224, 1), new d("ImageProcessingIFDPointer", 8256, 1) };', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Camera-for-OPPO-HD-Camera-1.2_exif_keyword.json', 'seq_num': 2}), Document(page_content='final d d93 = new d("GPSMapDatum", 18, 2);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Camera-for-OPPO-HD-Camera-1.2_exif_keyword.json', 'seq_num': 3}), Document(page_content='final d d87 = new d("GPSSpeedRef", 12, 2);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Camera-for-OPPO-HD-Camera-1.2_exif_keyword.json', 'seq_num': 4}), Document(page_content='final d d97 = new d("GPSDestLongitude", 22, 5);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Camera-for-OPPO-HD-Camera-1.2_exif_keyword.json', 'seq_num': 5}), Document(page_content='final d d94 = new d("GPSDestLatitudeRef", 19, 2);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Camera-for-OPPO-HD-Camera-1.2_exif_keyword.json', 'seq_num': 6}), Document(page_content='final d d103 = new d("GPSAreaInformation", 28, 7);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Camera-for-OPPO-HD-Camera-1.2_exif_keyword.json', 'seq_num': 7}), Document(page_content='if (string.equals("GPSTimeStamp")) {', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Camera-for-OPPO-HD-Camera-1.2_exif_keyword.json', 'seq_num': 8}), Document(page_content='final d d96 = new d("GPSDestLongitudeRef", 21, 2);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Camera-for-OPPO-HD-Camera-1.2_exif_keyword.json', 'seq_num': 9}), Document(page_content='final d d92 = new d("GPSImgDirection", 17, 5);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Camera-for-OPPO-HD-Camera-1.2_exif_keyword.json', 'seq_num': 10}), Document(page_content='final d d101 = new d("GPSDestDistance", 26, 5);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Camera-for-OPPO-HD-Camera-1.2_exif_keyword.json', 'seq_num': 11}), Document(page_content='final d d89 = new d("GPSTrackRef", 14, 2);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Camera-for-OPPO-HD-Camera-1.2_exif_keyword.json', 'seq_num': 12}), Document(page_content='final d d79 = new d("GPSLongitude", 4, 5);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Camera-for-OPPO-HD-Camera-1.2_exif_keyword.json', 'seq_num': 13}), Document(page_content='final StringBuilder a2 = android.support.v4.media.c.a("GPS Timestamp format is not rational. format=");', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Camera-for-OPPO-HD-Camera-1.2_exif_keyword.json', 'seq_num': 14}), Document(page_content='final d d86 = new d("GPSDOP", 11, 5);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Camera-for-OPPO-HD-Camera-1.2_exif_keyword.json', 'seq_num': 15}), Document(page_content='final d d70 = new d("LensMake", 42035, 2);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Camera-for-OPPO-HD-Camera-1.2_exif_keyword.json', 'seq_num': 16}), Document(page_content='this.a = (!b2 && (Build$VERSION.SDK_INT != 27 || !Arrays.asList("LG-M250", "LG-M320", "LG-Q710AL", "LG-Q710PL", "LGM-K121K", "LGM-K121L", "LGM-K121S", "LGM-X320K", "LGM-X320L", "LGM-X320S", "LGM-X401L", "LGM-X401S", " ...
# ------------------------- Loop-11-------------------------
# File :./exif_keyword_code_block_re/Calculator-Lock-Gallery-Vault-2.1_exif_keyword.json
# Length exif_keyword_code json_loader: 70
# [Document(page_content='x0.h("ImageCapture", "Unable to support software JPEG. Disabling.");', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Calculator-Lock-Gallery-Vault-2.1_exif_keyword.json', 'seq_num': 1}), Document(page_content='final e e89 = new e("GPSTrackRef", 14, 2);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Calculator-Lock-Gallery-Vault-2.1_exif_keyword.json', 'seq_num': 2}), Document(page_content='final e e99 = new e("GPSDestBearing", 24, 5);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Calculator-Lock-Gallery-Vault-2.1_exif_keyword.json', 'seq_num': 3}), Document(page_content='final e e103 = new e("GPSAreaInformation", 28, 7);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Calculator-Lock-Gallery-Vault-2.1_exif_keyword.json', 'seq_num': 4}), Document(page_content='if (key.equals("GPSTimeStamp")) {', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Calculator-Lock-Gallery-Vault-2.1_exif_keyword.json', 'seq_num': 5}), Document(page_content='final e e128 = new e("Software", 305, 2);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Calculator-Lock-Gallery-Vault-2.1_exif_keyword.json', 'seq_num': 6}), Document(page_content='final e e95 = new e("GPSDestLatitude", 20, 5);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Calculator-Lock-Gallery-Vault-2.1_exif_keyword.json', 'seq_num': 7}), Document(page_content='final e e32 = new e("MakerNote", 37500, 7);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Calculator-Lock-Gallery-Vault-2.1_exif_keyword.json', 'seq_num': 8}), Document(page_content='final e e104 = new e("GPSDateStamp", 29, 2);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Calculator-Lock-Gallery-Vault-2.1_exif_keyword.json', 'seq_num': 9}), Document(page_content='final e e116 = new e("Make", 271, 2);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Calculator-Lock-Gallery-Vault-2.1_exif_keyword.json', 'seq_num': 10}), Document(page_content='if (!"DateTime".equals(s) && !"DateTimeOriginal".equals(s)) {', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Calculator-Lock-Gallery-Vault-2.1_exif_keyword.json', 'seq_num': 11}), Document(page_content='final e e82 = new e("GPSTimeStamp", 7, 5);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Calculator-Lock-Gallery-Vault-2.1_exif_keyword.json', 'seq_num': 12}), Document(page_content='final d d = this.f[1].get("MakerNote");', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Calculator-Lock-Gallery-Vault-2.1_exif_keyword.json', 'seq_num': 13}), Document(page_content='final String k = this.k("DateTimeOriginal");', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Calculator-Lock-Gallery-Vault-2.1_exif_keyword.json', 'seq_num': 14}), Document(page_content='if (string.equals("GPSTimeStamp")) {', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Calculator-Lock-Gallery-Vault-2.1_exif_keyword.json', 'seq_num': 15}), Document(page_content='final e e91 = new e("GPSImgDirectionRef", 16, 2);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Calculator-Lock-Gallery-Vault-2.1_exif_keyword.json', 'seq_num': 16}), Document(page_content='final e e14 = new e("DateTimeOriginal", 36867, 2);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Calculator-Lock-Gallery-Vault-2.1_exif_keyword.json', 'seq_num': 17}), Document(page_content='final e e70 = new e("LensMake", 42035, 2);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Calculator-Lock-Gallery-Vault-2.1_exif_keyword.json', 'seq_num' ...
# ------------------------- Loop-12-------------------------
# File :./exif_keyword_code_block_re/Google_Drive_exif_keyword.json
# Length exif_keyword_code json_loader: 15
# ...
# ------------------------- Loop-181-------------------------
# File :./exif_keyword_code_block_re/Simple-File-Manager-5.3.3_exif_keyword.json
# Length exif_keyword_code json_loader: 43
# [Document(page_content='final String l = this.l("GPSLatitude");', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Simple-File-Manager-5.3.3_exif_keyword.json', 'seq_num': 1}), Document(page_content='public static final int assume_strong_biometrics_models = 2130903040;', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Simple-File-Manager-5.3.3_exif_keyword.json', 'seq_num': 2}), Document(page_content='import com.simplemobiletools.commons.models.FileDirItem;', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Simple-File-Manager-5.3.3_exif_keyword.json', 'seq_num': 3}), Document(page_content='r0 = new HashSet<String>(Arrays.asList("FNumber", "DigitalZoomRatio", "ExposureTime", "SubjectDistance", "GPSTimeStamp"));', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Simple-File-Manager-5.3.3_exif_keyword.json', 'seq_num': 4}), Document(page_content='final String i = this.l("GPSLatitudeRef");', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Simple-File-Manager-5.3.3_exif_keyword.json', 'seq_num': 5}), Document(page_content='final e[] array5 = f0 = new e[] { new e("NewSubfileType", 254, 4), new e("SubfileType", 255, 4), new e("ThumbnailImageWidth", 256, 3, 4), new e("ThumbnailImageLength", 257, 3, 4), new e("BitsPerSample", 258, 3), new e("Compression", 259, 3), new e("PhotometricInterpretation", 262, 3), new e("ImageDescription", 270, 2), new e("Make", 271, 2), new e("Model", 272, 2), new e("StripOffsets", 273, 3, 4), new e("ThumbnailOrientation", 274, 3), new e("SamplesPerPixel", 277, 3), new e("RowsPerStrip", 278, 3, 4), new e("StripByteCounts", 279, 3, 4), new e("XResolution", 282, 5), new e("YResolution", 283, 5), new e("PlanarConfiguration", 284, 3), new e("ResolutionUnit", 296, 3), new e("TransferFunction", 301, 3), new e("Software", 305, 2), new e("DateTime", 306, 2), new e("Artist", 315, 2), new e("WhitePoint", 318, 5), new e("PrimaryChromaticities", 319, 5), new e("SubIFDPointer", 330, 4), new e("JPEGInterchangeFormat", 513, 4), new e("JPEGInterchangeFormatLength", 514, 4), new e("YCbCrCoefficients", 529, 5), new e("YCbCrSubSampling", 530, 3), new e("YCbCrPositioning", 531, 3), new e("ReferenceBlackWhite", 532, 5), new e("Copyright", 33432, 2), new e("ExifIFDPointer", 34665, 4), new e("GPSInfoIFDPointer", 34853, 4), new e("DNGVersion", 50706, 1), new e("DefaultCropSize", 50720, 3, 4) };', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Simple-File-Manager-5.3.3_exif_keyword.json', 'seq_num': 6}), Document(page_content='this.f[0].put("DateTime", d0.a.d.e(l));', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Simple-File-Manager-5.3.3_exif_keyword.json', 'seq_num': 7}), Document(page_content='final d d = this.f[1].get("MakerNote");', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Simple-File-Manager-5.3.3_exif_keyword.json', 'seq_num': 8}), Document(page_content='final String k = this.l("GPSLongitudeRef");', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Simple-File-Manager-5.3.3_exif_keyword.json', 'seq_num': 9}), Document(page_content='final String exifCameraModel = ExifInterfaceKt.getExifCameraModel(a);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Simple-File-Manager-5.3.3_exif_keyword.json', 'seq_num': 10}), Document(page_content='sb.append("Latitude/longitude values are not parsable. ");', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Simple-File-Manager-5.3.3_exif_keyword.json', 'seq_num': 11}), Document(page_content='return Build$VERSION.SDK_INT == 27 && Arrays.asList("LG-M250", "LG-M320", "LG-Q710AL", "LG-Q710PL", "LGM-K121K", "LGM-K121L", "LGM-K121S", "LGM-X320K", "LGM-X320L", "LGM-X320S", "LGM-X401L", "LGM-X401S", "LM-Q610.FG", "LM-Q610.FGN", "LM-Q617.F ...
# ------------------------- Loop-182-------------------------
# File :./exif_keyword_code_block_re/Heart-Frames-Love-Photos-2.9_exif_keyword.json
# Length exif_keyword_code json_loader: 0
# []
# ------------------------- Loop-183-------------------------
# File :./exif_keyword_code_block_re/Camera-for-OPPO-OPPO-Camera-2.1_exif_keyword.json
# Length exif_keyword_code json_loader: 65
# [Document(page_content='final e e89 = new e("GPSTrackRef", 14, 2);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Camera-for-OPPO-OPPO-Camera-2.1_exif_keyword.json', 'seq_num': 1}), Document(page_content='final e e99 = new e("GPSDestBearing", 24, 5);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Camera-for-OPPO-OPPO-Camera-2.1_exif_keyword.json', 'seq_num': 2}), Document(page_content='final e e103 = new e("GPSAreaInformation", 28, 7);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Camera-for-OPPO-OPPO-Camera-2.1_exif_keyword.json', 'seq_num': 3}), Document(page_content='if (key.equals("GPSTimeStamp")) {', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Camera-for-OPPO-OPPO-Camera-2.1_exif_keyword.json', 'seq_num': 4}), Document(page_content='final StringBuilder x2 = a3.a.x("Invalid GPS Timestamp array. array=");', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Camera-for-OPPO-OPPO-Camera-2.1_exif_keyword.json', 'seq_num': 5}), Document(page_content='final e e128 = new e("Software", 305, 2);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Camera-for-OPPO-OPPO-Camera-2.1_exif_keyword.json', 'seq_num': 6}), Document(page_content='final e e95 = new e("GPSDestLatitude", 20, 5);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Camera-for-OPPO-OPPO-Camera-2.1_exif_keyword.json', 'seq_num': 7}), Document(page_content='final e e32 = new e("MakerNote", 37500, 7);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Camera-for-OPPO-OPPO-Camera-2.1_exif_keyword.json', 'seq_num': 8}), Document(page_content='final e e104 = new e("GPSDateStamp", 29, 2);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Camera-for-OPPO-OPPO-Camera-2.1_exif_keyword.json', 'seq_num': 9}), Document(page_content='final e e116 = new e("Make", 271, 2);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Camera-for-OPPO-OPPO-Camera-2.1_exif_keyword.json', 'seq_num': 10}), Document(page_content='final e e82 = new e("GPSTimeStamp", 7, 5);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Camera-for-OPPO-OPPO-Camera-2.1_exif_keyword.json', 'seq_num': 11}), Document(page_content='final d d = this.f[1].get("MakerNote");', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Camera-for-OPPO-OPPO-Camera-2.1_exif_keyword.json', 'seq_num': 12}), Document(page_content='if (string.equals("GPSTimeStamp")) {', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Camera-for-OPPO-OPPO-Camera-2.1_exif_keyword.json', 'seq_num': 13}), Document(page_content='final e e91 = new e("GPSImgDirectionRef", 16, 2);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Camera-for-OPPO-OPPO-Camera-2.1_exif_keyword.json', 'seq_num': 14}), Document(page_content='final e e14 = new e("DateTimeOriginal", 36867, 2);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Camera-for-OPPO-OPPO-Camera-2.1_exif_keyword.json', 'seq_num': 15}), Document(page_content='final StringBuilder x = a3.a.x("GPS Timestamp format is not rational. format=");', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Camera-for-OPPO-OPPO-Camera-2.1_exif_keyword.json', 'seq_num': 16}), Document(page_content='final e e11 = new e("ISOSpeedLatitudeyyy", 34868, 4);', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Camera-for-OPPO-OPPO-Camera-2.1_exif_keyword.json', 'seq_num': 17}), Document(page_content='a0 = new HashSet<String>(Arrays.asList("FNumber", "DigitalZoomRatio", "ExposureTime", "SubjectDistance", "GPSTimeStamp"));', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_ ...
# ------------------------- Loop-184-------------------------
# File :./exif_keyword_code_block_re/Pomelo-Camera-Photo-editor-3.0.213_exif_keyword.json
# Length exif_keyword_code json_loader: 85
# [Document(page_content='final String k = this.j("GPSLongitude");', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Pomelo-Camera-Photo-editor-3.0.213_exif_keyword.json', 'seq_num': 1}), Document(page_content='sb2.append("Longitude value ");', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Pomelo-Camera-Photo-editor-3.0.213_exif_keyword.json', 'seq_num': 2}), Document(page_content='E6 = new HashSet<String>(Arrays.asList("FNumber", "DigitalZoomRatio", "ExposureTime", "SubjectDistance", "GPSTimeStamp"));', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Pomelo-Camera-Photo-editor-3.0.213_exif_keyword.json', 'seq_num': 3}), Document(page_content='public static final String t1 = "GPSLongitude";', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Pomelo-Camera-Photo-editor-3.0.213_exif_keyword.json', 'seq_num': 4}), Document(page_content='public static final String n1 = "LensModel";', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Pomelo-Camera-Photo-editor-3.0.213_exif_keyword.json', 'seq_num': 5}), Document(page_content='public static final String T = "Model";', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Pomelo-Camera-Photo-editor-3.0.213_exif_keyword.json', 'seq_num': 6}), Document(page_content='public static final String m1 = "LensMake";', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Pomelo-Camera-Photo-editor-3.0.213_exif_keyword.json', 'seq_num': 7}), Document(page_content='public static final String L1 = "GPSDestLongitude";', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Pomelo-Camera-Photo-editor-3.0.213_exif_keyword.json', 'seq_num': 8}), Document(page_content='if ("MakerNote".equals(d.b)) {', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Pomelo-Camera-Photo-editor-3.0.213_exif_keyword.json', 'seq_num': 9}), Document(page_content='this.b0("GPSLongitude", this.c(Math.abs(d)));', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Pomelo-Camera-Photo-editor-3.0.213_exif_keyword.json', 'seq_num': 10}), Document(page_content='public static final String K1 = "GPSDestLongitudeRef";', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Pomelo-Camera-Photo-editor-3.0.213_exif_keyword.json', 'seq_num': 11}), Document(page_content='public static final String I1 = "GPSDestLatitudeRef";', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Pomelo-Camera-Photo-editor-3.0.213_exif_keyword.json', 'seq_num': 12}), Document(page_content='this.b0("GPSSpeedRef", "K");', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Pomelo-Camera-Photo-editor-3.0.213_exif_keyword.json', 'seq_num': 13}), Document(page_content='sb.append("Latitude value ");', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Pomelo-Camera-Photo-editor-3.0.213_exif_keyword.json', 'seq_num': 14}), Document(page_content='public static final String j0 = "DateTimeDigitized";', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Pomelo-Camera-Photo-editor-3.0.213_exif_keyword.json', 'seq_num': 15}), Document(page_content='final c c = this.d[1].get("MakerNote");', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Pomelo-Camera-Photo-editor-3.0.213_exif_keyword.json', 'seq_num': 16}), Document(page_content='public static final String U = "Software";', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Pomelo-Camera-Photo-editor-3.0.213_exif_keyword.json', 'seq_num': 17}), Document(page_content='public static final String T1 = "GPSDifferential";', metadata={'source': '/root/metaLeak-ml-llm-rag-ubuntu/exif_keyword_code_block_re/Pomelo-Camera-Photo ...
# *****************************************************************************
# Length exif_keyword_code json_loader total: 9926
# *****************************************************************************

# %%
print("==============================VECTOR STORE======================================")
vector_handle = FAISS.from_documents(exif_keyword_code_documents_total,embeddings) # ingest documents into the vector store 
print("Length vector exif_keyword_code : "+str(vector_handle.index.ntotal)) 
# print(vector_declare.index_to_docstore_id)
# save local
remove_directory("faiss_vector_exif_keyword_index_db")
vector_declare.save_local("faiss_vector_exif_keyword_index_db")
# Out:
# ==============================VECTOR STORE======================================
# Length vector exif_keyword_code : 9926
# Directory 'faiss_vector_exif_keyword_index_db' does not exist.
