# %%
import os

# %%
def count_words(file_path):
    word_count = 0
    with open(file_path, 'r') as file:
        for line in file:
            words = line.split()
            word_count += len(words)
    return word_count
def get_all_directories(path):
    directories = []
    for entry in os.listdir(path):
        full_path = os.path.join(path, entry)
        if os.path.isdir(full_path):
            directories.append(entry)
    return directories
# Get all file in directory
def get_all_files_in_directory(directory_path):
    # Initialize an empty list to store file names
    file_list = []

    # Iterate through all files and directories in the specified directory
    for item in os.listdir(directory_path):
        # Construct the full path of the item
        full_path = os.path.join(directory_path, item)

        # Check if the item is a file (not a directory)
        if os.path.isfile(full_path):
            # Add the file to the list
            file_list.append(full_path)
    return file_list
def calculate_sum(numbers):
    total_sum = 0
    for number in numbers:
        total_sum += number
    return total_sum

# %%
group_3_path = r'.\grouping\group-3'
directories = get_all_directories(group_3_path)
array_word = []
for i in range(len(directories)):
    directory = group_3_path+"\\"+str(directories[i])
    print(directory)
    files = get_all_files_in_directory(directory)
    for j in range(len(files)):
        word = count_words(files[j])
        array_word.append(word)
        print(word)
print(array_word)
total = calculate_sum(array_word)
print(total)
# Out:
# .\grouping\group-3\500px-Photography-Community-7.6.0.0
# 10778
# 980
# 1062
# 1729
# 903
# 218
# 48
# 313
# 975
# 8732
# 411
# 1270
# 794
# 5050
# 1530
# 1779
# 4888
# .\grouping\group-3\A-Gallery-Photos-Videos-2.2.66.2
# 14389
# .\grouping\group-3\Air-Camera-Photo-Editor-Collage-Filter-1.9.5.1018
# 1793
# 2722
# 1457
# 459
# 370
# 381
# .\grouping\group-3\Amazon-Photos_2.10.0.494.0
# 6201
# .\grouping\group-3\AndroZip-FREE-File-Manager-4.7.4
# .\grouping\group-3\AngleCam-Lite-Angular-Camera-5.14
# 12279
# .\grouping\group-3\ASTRO-8.12.0
# 200
# 1313
# 792
# 12
# 410
# 1361
# 9075
# 995
# .\grouping\group-3\Aves-Gallery-1.8.9
# 1411
# 693
# 8973
# 9375
# 1645
# 1068
# 721
# 691
# 508
# .\grouping\group-3\B216-Selfie-Beauty-Camera-2.1
# 400
# 4013
# 670
# 2908
# 964
# 3095
# 16
# 201
# 2087
# 214
# 38
# 77
# 113
# 127
# 320
# .\grouping\group-3\Beauty-Camera-Selfie-Camera-2.6.7
# 8943
# 2623
# 1440
# 1449
# 603
# .\grouping\group-3\Beauty-Camera-Selfie-Sticker-3.2.5
# 8944
# 2623
# ...
