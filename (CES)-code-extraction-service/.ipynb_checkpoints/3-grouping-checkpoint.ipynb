# %% [markdown]
# # GROUPING SOURCE CODE

# %%
import os
import shutil
import pandas as pd

# %% [markdown]
# ## 1. FUNCTION

# %%
# Function get directory
def get_all_directories(path):
    directories = []
    for entry in os.listdir(path):
        full_path = os.path.join(path, entry)
        if os.path.isdir(full_path):
            directories.append(entry)
    return directories
# Get all file in directory
def get_all_files_in_directory(directory_path):
    # Initialize an empty list to store file names
    file_list = []

    # Iterate through all files and directories in the specified directory
    for item in os.listdir(directory_path):
        # Construct the full path of the item
        full_path = os.path.join(directory_path, item)

        # Check if the item is a file (not a directory)
        if os.path.isfile(full_path):
            # Add the file to the list
            file_list.append(full_path)
    return file_list
# Function search file path that contain keywork
def find_files_with_keyword(directory, keyword):
    matching_files = []
    for root, _, files in os.walk(directory):
        for file in files:
            file_path = os.path.join(root, file)
            try:
                with open(file_path, 'r', encoding='utf-8') as f:
                    content = f.read()
                    if keyword in content:
                        matching_files.append(file_path)
            except Exception as e:
                print(f"Error reading {file_path}: {e}")
    return matching_files
# Function copy directory
def copy_directory(src_dir, dest_dir):
    try:
        # Copy the entire directory tree recursively
        shutil.copytree(src_dir, dest_dir)
        print(f"Directory '{src_dir}' copied to '{dest_dir}' successfully.")
    except FileExistsError:
        print(f"Directory '{dest_dir}' already exists.")
    except Exception as e:
        print(f"An error occurred: {e}")
# Update CSV
def update_csv_group(csv_file, apkfile_name, group):
    try:
        # Read the CSV file into a DataFrame
        df = pd.read_csv(csv_file)
        
        # Update the "exif_file_no" column where "apkfile_name" matches the given value
        df.loc[df['apkfile_name'] == apkfile_name, 'group'] = int(group)
        
        # Write the updated DataFrame back to the CSV file
        df.to_csv(csv_file, index=False)
        
        print(f"CSV file '{csv_file}' updated successfully.")
    except FileNotFoundError:
        print("CSV file not found.")
    except Exception as e:
        print(f"An error occurred while updating the CSV file: {e}")

# %% [markdown]
# ## 2. STATIC VARIABLE

# %%
exif_java_directory = r".\exif-java"
csv_file = "paper_report_intent.csv"
group_1 = r".\grouping\group-1"
group_2 = r".\grouping\group-2"
group_3 = r".\grouping\group-3"

# %% [markdown]
# ## 3. MAIN

# %%
directories = get_all_directories(exif_java_directory)
for i in range(len(directories)):
    print("-------------------Loop "+str(i)+": "+str(directories[i])+"-------------------")
    src_directory = exif_java_directory+"\\"+directories[i]
    print(src_directory)
    apkfile_name = directories[i]+".apk"
    if(len(find_files_with_keyword(src_directory, "android.media.ExifInterface"))>0):
        copy_directory(src_directory, group_1+"\\"+directories[i])
        update_csv_group(csv_file, apkfile_name, 1)
    elif(len(find_files_with_keyword(src_directory, "androidx.exifinterface.media"))>0):
        copy_directory(src_directory, group_2+"\\"+directories[i])
        update_csv_group(csv_file, apkfile_name, 2)
    else:
        copy_directory(src_directory, group_3+"\\"+directories[i])
        update_csv_group(csv_file, apkfile_name, 3)
# Out:
# -------------------Loop 0: 16-Megapixel-HDr-Camera-1.1-------------------
# .\exif-java\16-Megapixel-HDr-Camera-1.1
# Directory '.\exif-java\16-Megapixel-HDr-Camera-1.1' copied to '.\grouping\group-1\16-Megapixel-HDr-Camera-1.1' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 1: 1998-Cam-Vintage-Camera-1.8.8-------------------
# .\exif-java\1998-Cam-Vintage-Camera-1.8.8
# Directory '.\exif-java\1998-Cam-Vintage-Camera-1.8.8' copied to '.\grouping\group-1\1998-Cam-Vintage-Camera-1.8.8' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 2: 1Gallery-Photo-Gallery-Vault-1.0.7-7.130123-------------------
# .\exif-java\1Gallery-Photo-Gallery-Vault-1.0.7-7.130123
# Directory '.\exif-java\1Gallery-Photo-Gallery-Vault-1.0.7-7.130123' copied to '.\grouping\group-2\1Gallery-Photo-Gallery-Vault-1.0.7-7.130123' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 3: 3D-Photo-Video-Gallery-Editor-1.6-------------------
# .\exif-java\3D-Photo-Video-Gallery-Editor-1.6
# Directory '.\exif-java\3D-Photo-Video-Gallery-Editor-1.6' copied to '.\grouping\group-1\3D-Photo-Video-Gallery-Editor-1.6' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 4: 3Q-Album-photo-organizer-5.0.0-------------------
# .\exif-java\3Q-Album-photo-organizer-5.0.0
# Directory '.\exif-java\3Q-Album-photo-organizer-5.0.0' copied to '.\grouping\group-1\3Q-Album-photo-organizer-5.0.0' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 5: 500px-Photography-Community-7.6.0.0-------------------
# .\exif-java\500px-Photography-Community-7.6.0.0
# Directory '.\exif-java\500px-Photography-Community-7.6.0.0' copied to '.\grouping\group-3\500px-Photography-Community-7.6.0.0' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 6: A-Better-Camera-3.52-------------------
# .\exif-java\A-Better-Camera-3.52
# Directory '.\exif-java\A-Better-Camera-3.52' copied to '.\grouping\group-1\A-Better-Camera-3.52' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 7: A-Gallery-Photos-Videos-2.2.66.2-------------------
# .\exif-java\A-Gallery-Photos-Videos-2.2.66.2
# Directory '.\exif-java\A-Gallery-Photos-Videos-2.2.66.2' copied to '.\grouping\group-3\A-Gallery-Photos-Videos-2.2.66.2' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 8: AfterFocus-2.1.0-------------------
# .\exif-java\AfterFocus-2.1.0
# Directory '.\exif-java\AfterFocus-2.1.0' copied to '.\grouping\group-1\AfterFocus-2.1.0' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 9: AI-Gallery-1.1.5-------------------
# .\exif-java\AI-Gallery-1.1.5
# Directory '.\exif-java\AI-Gallery-1.1.5' copied to '.\grouping\group-1\AI-Gallery-1.1.5' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 10: AI-Gallery-4.8.5.92-------------------
# .\exif-java\AI-Gallery-4.8.5.92
# Directory '.\exif-java\AI-Gallery-4.8.5.92' copied to '.\grouping\group-1\AI-Gallery-4.8.5.92' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 11: Air-Camera-Photo-Editor-Collage-Filter-1.9.5.1018-------------------
# .\exif-java\Air-Camera-Photo-Editor-Collage-Filter-1.9.5.1018
# Directory '.\exif-java\Air-Camera-Photo-Editor-Collage-Filter-1.9.5.1018' copied to '.\grouping\group-3\Air-Camera-Photo-Editor-Collage-Filter-1.9.5.1018' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 12: Amaze-3.8.5-------------------
# .\exif-java\Amaze-3.8.5
# Directory '.\exif-java\Amaze-3.8.5' copied to '.\grouping\group-2\Amaze-3.8.5' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 13: Amazon-Photos_2.10.0.494.0-------------------
# .\exif-java\Amazon-Photos_2.10.0.494.0
# Directory '.\exif-java\Amazon-Photos_2.10.0.494.0' copied to '.\grouping\group-3\Amazon-Photos_2.10.0.494.0' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 14: AndroZip-FREE-File-Manager-4.7.4-------------------
# .\exif-java\AndroZip-FREE-File-Manager-4.7.4
# Directory '.\exif-java\AndroZip-FREE-File-Manager-4.7.4' copied to '.\grouping\group-3\AndroZip-FREE-File-Manager-4.7.4' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 15: AnExplorer-TV-File-Manager_5.2.2-------------------
# .\exif-java\AnExplorer-TV-File-Manager_5.2.2
# Directory '.\exif-java\AnExplorer-TV-File-Manager_5.2.2' copied to '.\grouping\group-2\AnExplorer-TV-File-Manager_5.2.2' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 16: AngleCam-Lite-Angular-Camera-5.14-------------------
# .\exif-java\AngleCam-Lite-Angular-Camera-5.14
# Directory '.\exif-java\AngleCam-Lite-Angular-Camera-5.14' copied to '.\grouping\group-3\AngleCam-Lite-Angular-Camera-5.14' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 17: AOSP-Gallery-speed.full-------------------
# .\exif-java\AOSP-Gallery-speed.full
# Directory '.\exif-java\AOSP-Gallery-speed.full' copied to '.\grouping\group-1\AOSP-Gallery-speed.full' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 18: AppFace-Face-app-Face-Editor-Gender-Changer-1.0-------------------
# .\exif-java\AppFace-Face-app-Face-Editor-Gender-Changer-1.0
# Directory '.\exif-java\AppFace-Face-app-Face-Editor-Gender-Changer-1.0' copied to '.\grouping\group-1\AppFace-Face-app-Face-Editor-Gender-Changer-1.0' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 19: ASTRO-8.12.0-------------------
# .\exif-java\ASTRO-8.12.0
# Directory '.\exif-java\ASTRO-8.12.0' copied to '.\grouping\group-3\ASTRO-8.12.0' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 20: ASUS-File-Manager-2.8.0.85_230220-------------------
# .\exif-java\ASUS-File-Manager-2.8.0.85_230220
# Directory '.\exif-java\ASUS-File-Manager-2.8.0.85_230220' copied to '.\grouping\group-1\ASUS-File-Manager-2.8.0.85_230220' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 21: Auto-Camera-1.23-------------------
# .\exif-java\Auto-Camera-1.23
# Directory '.\exif-java\Auto-Camera-1.23' copied to '.\grouping\group-2\Auto-Camera-1.23' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 22: Auto-Stamper-Date-Timestamp-3.18.2-------------------
# .\exif-java\Auto-Stamper-Date-Timestamp-3.18.2
# Directory '.\exif-java\Auto-Stamper-Date-Timestamp-3.18.2' copied to '.\grouping\group-1\Auto-Stamper-Date-Timestamp-3.18.2' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 23: Auto-Timestamp-Camera-Date-1.5-------------------
# .\exif-java\Auto-Timestamp-Camera-Date-1.5
# Directory '.\exif-java\Auto-Timestamp-Camera-Date-1.5' copied to '.\grouping\group-1\Auto-Timestamp-Camera-Date-1.5' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 24: Aves-Gallery-1.8.9-------------------
# .\exif-java\Aves-Gallery-1.8.9
# Directory '.\exif-java\Aves-Gallery-1.8.9' copied to '.\grouping\group-3\Aves-Gallery-1.8.9' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 25: Awesome-Camera-1-------------------
# .\exif-java\Awesome-Camera-1
# Directory '.\exif-java\Awesome-Camera-1' copied to '.\grouping\group-1\Awesome-Camera-1' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 26: B216-Selfie-Beauty-Camera-2.1-------------------
# .\exif-java\B216-Selfie-Beauty-Camera-2.1
# Directory '.\exif-java\B216-Selfie-Beauty-Camera-2.1' copied to '.\grouping\group-3\B216-Selfie-Beauty-Camera-2.1' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 27: B612-12.1.10-------------------
# .\exif-java\B612-12.1.10
# Directory '.\exif-java\B612-12.1.10' copied to '.\grouping\group-1\B612-12.1.10' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 28: Background-Camera-3.7.4-------------------
# .\exif-java\Background-Camera-3.7.4
# Directory '.\exif-java\Background-Camera-3.7.4' copied to '.\grouping\group-1\Background-Camera-3.7.4' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 29: Beauty-Art-Photo-editor-Free-photo-editing-apps-1.0.3-------------------
# .\exif-java\Beauty-Art-Photo-editor-Free-photo-editing-apps-1.0.3
# Directory '.\exif-java\Beauty-Art-Photo-editor-Free-photo-editing-apps-1.0.3' copied to '.\grouping\group-1\Beauty-Art-Photo-editor-Free-photo-editing-apps-1.0.3' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 30: Beauty-Camera-Selfie-Camera-1.8.1-------------------
# .\exif-java\Beauty-Camera-Selfie-Camera-1.8.1
# Directory '.\exif-java\Beauty-Camera-Selfie-Camera-1.8.1' copied to '.\grouping\group-1\Beauty-Camera-Selfie-Camera-1.8.1' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 31: Beauty-Camera-Selfie-Camera-2.6.7-------------------
# .\exif-java\Beauty-Camera-Selfie-Camera-2.6.7
# Directory '.\exif-java\Beauty-Camera-Selfie-Camera-2.6.7' copied to '.\grouping\group-3\Beauty-Camera-Selfie-Camera-2.6.7' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 32: Beauty-Camera-Selfie-Camera-4.0.5-------------------
# .\exif-java\Beauty-Camera-Selfie-Camera-4.0.5
# Directory '.\exif-java\Beauty-Camera-Selfie-Camera-4.0.5' copied to '.\grouping\group-1\Beauty-Camera-Selfie-Camera-4.0.5' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 33: Beauty-Camera-Selfie-Sticker-3.2.5-------------------
# .\exif-java\Beauty-Camera-Selfie-Sticker-3.2.5
# Directory '.\exif-java\Beauty-Camera-Selfie-Sticker-3.2.5' copied to '.\grouping\group-3\Beauty-Camera-Selfie-Sticker-3.2.5' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 34: Beauty-Camera-V-Camera-Editor-3.2.5-------------------
# .\exif-java\Beauty-Camera-V-Camera-Editor-3.2.5
# Directory '.\exif-java\Beauty-Camera-V-Camera-Editor-3.2.5' copied to '.\grouping\group-1\Beauty-Camera-V-Camera-Editor-3.2.5' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 35: Beauty-Camera-with-PhotoEditor-4.0.7-------------------
# .\exif-java\Beauty-Camera-with-PhotoEditor-4.0.7
# Directory '.\exif-java\Beauty-Camera-with-PhotoEditor-4.0.7' copied to '.\grouping\group-1\Beauty-Camera-with-PhotoEditor-4.0.7' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 36: Beauty-Camera-X-Selfie-Camera-8.8-------------------
# .\exif-java\Beauty-Camera-X-Selfie-Camera-8.8
# Directory '.\exif-java\Beauty-Camera-X-Selfie-Camera-8.8' copied to '.\grouping\group-2\Beauty-Camera-X-Selfie-Camera-8.8' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 37: Beauty-plus-Plus-camera-2.0.3-------------------
# .\exif-java\Beauty-plus-Plus-camera-2.0.3
# Directory '.\exif-java\Beauty-plus-Plus-camera-2.0.3' copied to '.\grouping\group-1\Beauty-plus-Plus-camera-2.0.3' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 38: Beauty-Selfie-Camera-2.0.4-------------------
# .\exif-java\Beauty-Selfie-Camera-2.0.4
# Directory '.\exif-java\Beauty-Selfie-Camera-2.0.4' copied to '.\grouping\group-1\Beauty-Selfie-Camera-2.0.4' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 39: Beauty-Selfie-Camera-2.0.5-------------------
# .\exif-java\Beauty-Selfie-Camera-2.0.5
# Directory '.\exif-java\Beauty-Selfie-Camera-2.0.5' copied to '.\grouping\group-1\Beauty-Selfie-Camera-2.0.5' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 40: Beauty-Selfie-Camera-Papaya-1.7.2-------------------
# .\exif-java\Beauty-Selfie-Camera-Papaya-1.7.2
# Directory '.\exif-java\Beauty-Selfie-Camera-Papaya-1.7.2' copied to '.\grouping\group-2\Beauty-Selfie-Camera-Papaya-1.7.2' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 41: BeautyCam-11.6.00-------------------
# .\exif-java\BeautyCam-11.6.00
# Directory '.\exif-java\BeautyCam-11.6.00' copied to '.\grouping\group-1\BeautyCam-11.6.00' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 42: BeautyPlus-7.6.021-------------------
# .\exif-java\BeautyPlus-7.6.021
# Directory '.\exif-java\BeautyPlus-7.6.021' copied to '.\grouping\group-1\BeautyPlus-7.6.021' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 43: BeFunky-7.1.11-------------------
# .\exif-java\BeFunky-7.1.11
# Directory '.\exif-java\BeFunky-7.1.11' copied to '.\grouping\group-3\BeFunky-7.1.11' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 44: BeReal-1.4.5-------------------
# .\exif-java\BeReal-1.4.5
# Directory '.\exif-java\BeReal-1.4.5' copied to '.\grouping\group-1\BeReal-1.4.5' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 45: Best-Camera-HD-3.2-------------------
# .\exif-java\Best-Camera-HD-3.2
# Directory '.\exif-java\Best-Camera-HD-3.2' copied to '.\grouping\group-1\Best-Camera-HD-3.2' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 46: BestCam-2018-1.0-------------------
# .\exif-java\BestCam-2018-1.0
# Directory '.\exif-java\BestCam-2018-1.0' copied to '.\grouping\group-1\BestCam-2018-1.0' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 47: Bimostitch-Panorama-Stitcher-2.9.24.1-lite-------------------
# .\exif-java\Bimostitch-Panorama-Stitcher-2.9.24.1-lite
# Directory '.\exif-java\Bimostitch-Panorama-Stitcher-2.9.24.1-lite' copied to '.\grouping\group-3\Bimostitch-Panorama-Stitcher-2.9.24.1-lite' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 48: Bluetooth-File-Transfer-5.666--------------------
# .\exif-java\Bluetooth-File-Transfer-5.666-
# Directory '.\exif-java\Bluetooth-File-Transfer-5.666-' copied to '.\grouping\group-3\Bluetooth-File-Transfer-5.666-' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 49: Bluetooth-Files-Transfer-6.2.902-------------------
# .\exif-java\Bluetooth-Files-Transfer-6.2.902
# Directory '.\exif-java\Bluetooth-Files-Transfer-6.2.902' copied to '.\grouping\group-2\Bluetooth-Files-Transfer-6.2.902' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 50: Bluetooth-Remote-Camera-1.5.1-------------------
# .\exif-java\Bluetooth-Remote-Camera-1.5.1
# Directory '.\exif-java\Bluetooth-Remote-Camera-1.5.1' copied to '.\grouping\group-3\Bluetooth-Remote-Camera-1.5.1' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 51: Boots-Photo-5.6.4-------------------
# .\exif-java\Boots-Photo-5.6.4
# Directory '.\exif-java\Boots-Photo-5.6.4' copied to '.\grouping\group-2\Boots-Photo-5.6.4' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 52: Box_6.16.8-------------------
# .\exif-java\Box_6.16.8
# Directory '.\exif-java\Box_6.16.8' copied to '.\grouping\group-1\Box_6.16.8' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 53: Brazzerfy-1.9-------------------
# .\exif-java\Brazzerfy-1.9
# Directory '.\exif-java\Brazzerfy-1.9' copied to '.\grouping\group-3\Brazzerfy-1.9' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 54: Calc-Box-Photo-video-locker-28.0-------------------
# .\exif-java\Calc-Box-Photo-video-locker-28.0
# Directory '.\exif-java\Calc-Box-Photo-video-locker-28.0' copied to '.\grouping\group-2\Calc-Box-Photo-video-locker-28.0' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 55: Calculator-Hide-Photo-Video-1.78-------------------
# .\exif-java\Calculator-Hide-Photo-Video-1.78
# Directory '.\exif-java\Calculator-Hide-Photo-Video-1.78' copied to '.\grouping\group-3\Calculator-Hide-Photo-Video-1.78' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 56: Calculator-Lock-3.5.17.4-------------------
# .\exif-java\Calculator-Lock-3.5.17.4
# Directory '.\exif-java\Calculator-Lock-3.5.17.4' copied to '.\grouping\group-1\Calculator-Lock-3.5.17.4' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 57: Calculator-Lock-App-Applock-1.4.1-------------------
# .\exif-java\Calculator-Lock-App-Applock-1.4.1
# Directory '.\exif-java\Calculator-Lock-App-Applock-1.4.1' copied to '.\grouping\group-3\Calculator-Lock-App-Applock-1.4.1' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 58: Calculator-Lock-App-Lock-2.2.1-------------------
# .\exif-java\Calculator-Lock-App-Lock-2.2.1
# Directory '.\exif-java\Calculator-Lock-App-Lock-2.2.1' copied to '.\grouping\group-1\Calculator-Lock-App-Lock-2.2.1' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 59: Calculator-Lock-Calc-Vault-1.0.15-------------------
# .\exif-java\Calculator-Lock-Calc-Vault-1.0.15
# Directory '.\exif-java\Calculator-Lock-Calc-Vault-1.0.15' copied to '.\grouping\group-2\Calculator-Lock-Calc-Vault-1.0.15' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 60: Calculator-Lock-Calculator-App-2.8.8-------------------
# .\exif-java\Calculator-Lock-Calculator-App-2.8.8
# Directory '.\exif-java\Calculator-Lock-Calculator-App-2.8.8' copied to '.\grouping\group-3\Calculator-Lock-Calculator-App-2.8.8' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 61: Calculator-Lock-Gallery-Vault-2.1-------------------
# .\exif-java\Calculator-Lock-Gallery-Vault-2.1
# Directory '.\exif-java\Calculator-Lock-Gallery-Vault-2.1' copied to '.\grouping\group-3\Calculator-Lock-Gallery-Vault-2.1' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 62: Calculator-Lock-Hide-App-Photo-3.51-------------------
# .\exif-java\Calculator-Lock-Hide-App-Photo-3.51
# Directory '.\exif-java\Calculator-Lock-Hide-App-Photo-3.51' copied to '.\grouping\group-1\Calculator-Lock-Hide-App-Photo-3.51' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 63: Calculator-Lock-Hide-Gallery-1.1.5-------------------
# .\exif-java\Calculator-Lock-Hide-Gallery-1.1.5
# Directory '.\exif-java\Calculator-Lock-Hide-Gallery-1.1.5' copied to '.\grouping\group-1\Calculator-Lock-Hide-Gallery-1.1.5' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 64: Calculator-Lock-Hide-Photo-2.6-------------------
# .\exif-java\Calculator-Lock-Hide-Photo-2.6
# Directory '.\exif-java\Calculator-Lock-Hide-Photo-2.6' copied to '.\grouping\group-3\Calculator-Lock-Hide-Photo-2.6' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 65: Calculator-Lock-HideZ-1.0.4-------------------
# .\exif-java\Calculator-Lock-HideZ-1.0.4
# Directory '.\exif-java\Calculator-Lock-HideZ-1.0.4' copied to '.\grouping\group-2\Calculator-Lock-HideZ-1.0.4' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 66: Calculator-Lock-Photo-Vault-1.0.8.2-------------------
# .\exif-java\Calculator-Lock-Photo-Vault-1.0.8.2
# Directory '.\exif-java\Calculator-Lock-Photo-Vault-1.0.8.2' copied to '.\grouping\group-1\Calculator-Lock-Photo-Vault-1.0.8.2' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 67: Calculator-Lock-Photo-Video-51-------------------
# .\exif-java\Calculator-Lock-Photo-Video-51
# Directory '.\exif-java\Calculator-Lock-Photo-Video-51' copied to '.\grouping\group-3\Calculator-Lock-Photo-Video-51' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 68: Calculator-Lock-Photo-Video-locker-Safe-Browser-1.0-------------------
# .\exif-java\Calculator-Lock-Photo-Video-locker-Safe-Browser-1.0
# Directory '.\exif-java\Calculator-Lock-Photo-Video-locker-Safe-Browser-1.0' copied to '.\grouping\group-3\Calculator-Lock-Photo-Video-locker-Safe-Browser-1.0' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 69: Calculator-photo-vault-10.7.1-------------------
# .\exif-java\Calculator-photo-vault-10.7.1
# Directory '.\exif-java\Calculator-photo-vault-10.7.1' copied to '.\grouping\group-2\Calculator-photo-vault-10.7.1' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 70: Calculator-Photo-Vault-Vid-3.2.1-------------------
# .\exif-java\Calculator-Photo-Vault-Vid-3.2.1
# Directory '.\exif-java\Calculator-Photo-Vault-Vid-3.2.1' copied to '.\grouping\group-3\Calculator-Photo-Vault-Vid-3.2.1' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 71: camera-1080p-full-hd-3.4.8-------------------
# .\exif-java\camera-1080p-full-hd-3.4.8
# Directory '.\exif-java\camera-1080p-full-hd-3.4.8' copied to '.\grouping\group-1\camera-1080p-full-hd-3.4.8' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 72: Camera-2019-1.53-------------------
# .\exif-java\Camera-2019-1.53
# Directory '.\exif-java\Camera-2019-1.53' copied to '.\grouping\group-1\Camera-2019-1.53' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 73: Camera-5G-2023.2-------------------
# .\exif-java\Camera-5G-2023.2
# Directory '.\exif-java\Camera-5G-2023.2' copied to '.\grouping\group-2\Camera-5G-2023.2' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 74: Camera-Auto-Timestamp-3.14-------------------
# .\exif-java\Camera-Auto-Timestamp-3.14
# Directory '.\exif-java\Camera-Auto-Timestamp-3.14' copied to '.\grouping\group-1\Camera-Auto-Timestamp-3.14' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 75: Camera-for-Android-5.7.3-------------------
# .\exif-java\Camera-for-Android-5.7.3
# Directory '.\exif-java\Camera-for-Android-5.7.3' copied to '.\grouping\group-1\Camera-for-Android-5.7.3' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 76: Camera-for-Android-HD-Camera-1.5.2-------------------
# .\exif-java\Camera-for-Android-HD-Camera-1.5.2
# Directory '.\exif-java\Camera-for-Android-HD-Camera-1.5.2' copied to '.\grouping\group-1\Camera-for-Android-HD-Camera-1.5.2' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 77: Camera-for-Android-HD-Camera-1.6.1-------------------
# .\exif-java\Camera-for-Android-HD-Camera-1.6.1
# Directory '.\exif-java\Camera-for-Android-HD-Camera-1.6.1' copied to '.\grouping\group-1\Camera-for-Android-HD-Camera-1.6.1' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 78: Camera-for-Galaxy-A20-Samsung-A20-Camera-1-------------------
# .\exif-java\Camera-for-Galaxy-A20-Samsung-A20-Camera-1
# Directory '.\exif-java\Camera-for-Galaxy-A20-Samsung-A20-Camera-1' copied to '.\grouping\group-1\Camera-for-Galaxy-A20-Samsung-A20-Camera-1' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 79: Camera-For-Galaxy-A50-Galaxy-A50-Camera-1.8-------------------
# .\exif-java\Camera-For-Galaxy-A50-Galaxy-A50-Camera-1.8
# Directory '.\exif-java\Camera-For-Galaxy-A50-Galaxy-A50-Camera-1.8' copied to '.\grouping\group-1\Camera-For-Galaxy-A50-Galaxy-A50-Camera-1.8' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 80: Camera-for-Galaxy-S22-HD-Ultra-1.2-------------------
# .\exif-java\Camera-for-Galaxy-S22-HD-Ultra-1.2
# Directory '.\exif-java\Camera-for-Galaxy-S22-HD-Ultra-1.2' copied to '.\grouping\group-1\Camera-for-Galaxy-S22-HD-Ultra-1.2' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 81: Camera-for-Galaxy-S23-Ultra-1.2-------------------
# .\exif-java\Camera-for-Galaxy-S23-Ultra-1.2
# Directory '.\exif-java\Camera-for-Galaxy-S23-Ultra-1.2' copied to '.\grouping\group-1\Camera-for-Galaxy-S23-Ultra-1.2' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 82: Camera-for-Galaxy-S23-Ultra-4K-122-------------------
# .\exif-java\Camera-for-Galaxy-S23-Ultra-4K-122
# Directory '.\exif-java\Camera-for-Galaxy-S23-Ultra-4K-122' copied to '.\grouping\group-1\Camera-for-Galaxy-S23-Ultra-4K-122' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 83: Camera-for-Galaxy-S23-Ultra-4k-5000.0.0-------------------
# .\exif-java\Camera-for-Galaxy-S23-Ultra-4k-5000.0.0
# Directory '.\exif-java\Camera-for-Galaxy-S23-Ultra-4k-5000.0.0' copied to '.\grouping\group-2\Camera-for-Galaxy-S23-Ultra-4k-5000.0.0' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 84: Camera-for-Galaxy-S23-Ultra-HD-5800.5.8.0-------------------
# .\exif-java\Camera-for-Galaxy-S23-Ultra-HD-5800.5.8.0
# Directory '.\exif-java\Camera-for-Galaxy-S23-Ultra-HD-5800.5.8.0' copied to '.\grouping\group-2\Camera-for-Galaxy-S23-Ultra-HD-5800.5.8.0' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 85: camera-for-galaxy-S9-S9-plus-sweet-selfie-4K-1.5-------------------
# .\exif-java\camera-for-galaxy-S9-S9-plus-sweet-selfie-4K-1.5
# Directory '.\exif-java\camera-for-galaxy-S9-S9-plus-sweet-selfie-4K-1.5' copied to '.\grouping\group-1\camera-for-galaxy-S9-S9-plus-sweet-selfie-4K-1.5' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 86: Camera-For-Galaxy-Z-Fold-4-65.0.0-------------------
# .\exif-java\Camera-For-Galaxy-Z-Fold-4-65.0.0
# Directory '.\exif-java\Camera-For-Galaxy-Z-Fold-4-65.0.0' copied to '.\grouping\group-2\Camera-For-Galaxy-Z-Fold-4-65.0.0' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 87: Camera-for-Huawei-Y9-Y9-Prime-2.5-------------------
# .\exif-java\Camera-for-Huawei-Y9-Y9-Prime-2.5
# Directory '.\exif-java\Camera-for-Huawei-Y9-Y9-Prime-2.5' copied to '.\grouping\group-1\Camera-for-Huawei-Y9-Y9-Prime-2.5' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 88: Camera-for-iphone-14-Camera-HD-1.0.80-------------------
# .\exif-java\Camera-for-iphone-14-Camera-HD-1.0.80
# Directory '.\exif-java\Camera-for-iphone-14-Camera-HD-1.0.80' copied to '.\grouping\group-3\Camera-for-iphone-14-Camera-HD-1.0.80' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 89: Camera-for-iphone-14-pro-max-11.0-------------------
# .\exif-java\Camera-for-iphone-14-pro-max-11.0
# Directory '.\exif-java\Camera-for-iphone-14-pro-max-11.0' copied to '.\grouping\group-1\Camera-for-iphone-14-pro-max-11.0' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 90: Camera-For-iPhone-20-Pro-Max-26.0.0-------------------
# .\exif-java\Camera-For-iPhone-20-Pro-Max-26.0.0
# Directory '.\exif-java\Camera-For-iPhone-20-Pro-Max-26.0.0' copied to '.\grouping\group-2\Camera-For-iPhone-20-Pro-Max-26.0.0' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 91: Camera-for-iPhone-X-1.4-------------------
# .\exif-java\Camera-for-iPhone-X-1.4
# Directory '.\exif-java\Camera-for-iPhone-X-1.4' copied to '.\grouping\group-1\Camera-for-iPhone-X-1.4' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 92: Camera-For-Mi-Xiaomi-Mi-12-1.0.4-------------------
# .\exif-java\Camera-For-Mi-Xiaomi-Mi-12-1.0.4
# Directory '.\exif-java\Camera-For-Mi-Xiaomi-Mi-12-1.0.4' copied to '.\grouping\group-1\Camera-For-Mi-Xiaomi-Mi-12-1.0.4' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 93: Camera-for-OPPO-HD-Camera-1.2-------------------
# .\exif-java\Camera-for-OPPO-HD-Camera-1.2
# Directory '.\exif-java\Camera-for-OPPO-HD-Camera-1.2' copied to '.\grouping\group-3\Camera-for-OPPO-HD-Camera-1.2' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 94: Camera-for-OPPO-OPPO-Camera-2.1-------------------
# .\exif-java\Camera-for-OPPO-OPPO-Camera-2.1
# Directory '.\exif-java\Camera-for-OPPO-OPPO-Camera-2.1' copied to '.\grouping\group-3\Camera-for-OPPO-OPPO-Camera-2.1' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 95: Camera-for-OPPO-Photo-Editor-2.0-------------------
# .\exif-java\Camera-for-OPPO-Photo-Editor-2.0
# Directory '.\exif-java\Camera-for-OPPO-Photo-Editor-2.0' copied to '.\grouping\group-3\Camera-for-OPPO-Photo-Editor-2.0' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 96: Camera-for-Oppo-Reno-6-Selfie-Expert-Camera-1.6-------------------
# .\exif-java\Camera-for-Oppo-Reno-6-Selfie-Expert-Camera-1.6
# Directory '.\exif-java\Camera-for-Oppo-Reno-6-Selfie-Expert-Camera-1.6' copied to '.\grouping\group-3\Camera-for-Oppo-Reno-6-Selfie-Expert-Camera-1.6' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 97: Camera-for-REDMI-K20-PRO-1.1-------------------
# .\exif-java\Camera-for-REDMI-K20-PRO-1.1
# Directory '.\exif-java\Camera-for-REDMI-K20-PRO-1.1' copied to '.\grouping\group-1\Camera-for-REDMI-K20-PRO-1.1' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 98: camera-for-samsung-Galaxy-j7-230.05.24-------------------
# .\exif-java\camera-for-samsung-Galaxy-j7-230.05.24
# Directory '.\exif-java\camera-for-samsung-Galaxy-j7-230.05.24' copied to '.\grouping\group-1\camera-for-samsung-Galaxy-j7-230.05.24' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 99: Camera-For-Samsung-Galaxy-S9-S9-Pro-01.01.2019-------------------
# .\exif-java\Camera-For-Samsung-Galaxy-S9-S9-Pro-01.01.2019
# Directory '.\exif-java\Camera-For-Samsung-Galaxy-S9-S9-Pro-01.01.2019' copied to '.\grouping\group-1\Camera-For-Samsung-Galaxy-S9-S9-Pro-01.01.2019' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 100: Camera-For-Sasmung-S22-Ultra-2.0-------------------
# .\exif-java\Camera-For-Sasmung-S22-Ultra-2.0
# Directory '.\exif-java\Camera-For-Sasmung-S22-Ultra-2.0' copied to '.\grouping\group-3\Camera-For-Sasmung-S22-Ultra-2.0' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 101: Camera-FV-5-Lite-5.3.3-------------------
# .\exif-java\Camera-FV-5-Lite-5.3.3
# Directory '.\exif-java\Camera-FV-5-Lite-5.3.3' copied to '.\grouping\group-3\Camera-FV-5-Lite-5.3.3' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 102: Camera-HD-Camera-1.1.2-------------------
# .\exif-java\Camera-HD-Camera-1.1.2
# Directory '.\exif-java\Camera-HD-Camera-1.1.2' copied to '.\grouping\group-1\Camera-HD-Camera-1.1.2' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 103: Camera-HD-Camera-for-Android-1.0.8-------------------
# .\exif-java\Camera-HD-Camera-for-Android-1.0.8
# Directory '.\exif-java\Camera-HD-Camera-for-Android-1.0.8' copied to '.\grouping\group-3\Camera-HD-Camera-for-Android-1.0.8' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 104: camera-huawei-mate-20-pro-selfie-huawei-mate20-8.5-------------------
# .\exif-java\camera-huawei-mate-20-pro-selfie-huawei-mate20-8.5
# Directory '.\exif-java\camera-huawei-mate-20-pro-selfie-huawei-mate20-8.5' copied to '.\grouping\group-1\camera-huawei-mate-20-pro-selfie-huawei-mate20-8.5' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 105: Camera-huawei-p20-pro-Selfie-huawei-p20-pro-6.6-------------------
# .\exif-java\Camera-huawei-p20-pro-Selfie-huawei-p20-pro-6.6
# Directory '.\exif-java\Camera-huawei-p20-pro-Selfie-huawei-p20-pro-6.6' copied to '.\grouping\group-1\Camera-huawei-p20-pro-Selfie-huawei-p20-pro-6.6' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 106: Camera-Huawei-P30-Pro-Camera-Huawei-P30-Plus-9.7-------------------
# .\exif-java\Camera-Huawei-P30-Pro-Camera-Huawei-P30-Plus-9.7
# Directory '.\exif-java\Camera-Huawei-P30-Pro-Camera-Huawei-P30-Plus-9.7' copied to '.\grouping\group-1\Camera-Huawei-P30-Pro-Camera-Huawei-P30-Plus-9.7' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 107: Camera-ICS-1.7.0-------------------
# .\exif-java\Camera-ICS-1.7.0
# Directory '.\exif-java\Camera-ICS-1.7.0' copied to '.\grouping\group-1\Camera-ICS-1.7.0' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 108: Camera-IPhone-13-Pro-Max-App-1.1-------------------
# .\exif-java\Camera-IPhone-13-Pro-Max-App-1.1
# Directory '.\exif-java\Camera-IPhone-13-Pro-Max-App-1.1' copied to '.\grouping\group-1\Camera-IPhone-13-Pro-Max-App-1.1' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 109: Camera-iphone-14-OS15-Camera-2.0.121-------------------
# .\exif-java\Camera-iphone-14-OS15-Camera-2.0.121
# Directory '.\exif-java\Camera-iphone-14-OS15-Camera-2.0.121' copied to '.\grouping\group-1\Camera-iphone-14-OS15-Camera-2.0.121' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 110: Camera-iphone-14-Pro-Max-4.0-------------------
# .\exif-java\Camera-iphone-14-Pro-Max-4.0
# Directory '.\exif-java\Camera-iphone-14-Pro-Max-4.0' copied to '.\grouping\group-1\Camera-iphone-14-Pro-Max-4.0' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 111: Camera-iphone-14-Pro-Max-OS16-6.0.1-------------------
# .\exif-java\Camera-iphone-14-Pro-Max-OS16-6.0.1
# Directory '.\exif-java\Camera-iphone-14-Pro-Max-OS16-6.0.1' copied to '.\grouping\group-1\Camera-iphone-14-Pro-Max-OS16-6.0.1' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 112: Camera-MX-1.0.1-------------------
# .\exif-java\Camera-MX-1.0.1
# Directory '.\exif-java\Camera-MX-1.0.1' copied to '.\grouping\group-2\Camera-MX-1.0.1' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 113: Camera-One-Wear-Galaxy-Watch-176-------------------
# .\exif-java\Camera-One-Wear-Galaxy-Watch-176
# Directory '.\exif-java\Camera-One-Wear-Galaxy-Watch-176' copied to '.\grouping\group-2\Camera-One-Wear-Galaxy-Watch-176' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 114: Camera-Oppo-Reno4-Selfie-Expert-for-Oppo-Reno4-1.2.2-------------------
# .\exif-java\Camera-Oppo-Reno4-Selfie-Expert-for-Oppo-Reno4-1.2.2
# Directory '.\exif-java\Camera-Oppo-Reno4-Selfie-Expert-for-Oppo-Reno4-1.2.2' copied to '.\grouping\group-3\Camera-Oppo-Reno4-Selfie-Expert-for-Oppo-Reno4-1.2.2' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 115: Camera-Roll-Gallery-v1.0.6-------------------
# .\exif-java\Camera-Roll-Gallery-v1.0.6
# Directory '.\exif-java\Camera-Roll-Gallery-v1.0.6' copied to '.\grouping\group-3\Camera-Roll-Gallery-v1.0.6' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 116: Camera-Sony-28.03.22-------------------
# .\exif-java\Camera-Sony-28.03.22
# Directory '.\exif-java\Camera-Sony-28.03.22' copied to '.\grouping\group-1\Camera-Sony-28.03.22' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 117: Camera-style-Samsung-Galaxy-S7-1.2-------------------
# .\exif-java\Camera-style-Samsung-Galaxy-S7-1.2
# Directory '.\exif-java\Camera-style-Samsung-Galaxy-S7-1.2' copied to '.\grouping\group-3\Camera-style-Samsung-Galaxy-S7-1.2' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 118: Camera-Timestamp-3.75-------------------
# .\exif-java\Camera-Timestamp-3.75
# Directory '.\exif-java\Camera-Timestamp-3.75' copied to '.\grouping\group-1\Camera-Timestamp-3.75' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 119: Camera-Xiaomi-Redmi-K20-Selfie-Xioami-K20-Pro-7.9-------------------
# .\exif-java\Camera-Xiaomi-Redmi-K20-Selfie-Xioami-K20-Pro-7.9
# Directory '.\exif-java\Camera-Xiaomi-Redmi-K20-Selfie-Xioami-K20-Pro-7.9' copied to '.\grouping\group-1\Camera-Xiaomi-Redmi-K20-Selfie-Xioami-K20-Pro-7.9' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 120: Camera-ZOOM-FX-6.3.0-------------------
# .\exif-java\Camera-ZOOM-FX-6.3.0
# Directory '.\exif-java\Camera-ZOOM-FX-6.3.0' copied to '.\grouping\group-1\Camera-ZOOM-FX-6.3.0' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 121: camera-zoom-moon-1.06-------------------
# .\exif-java\camera-zoom-moon-1.06
# Directory '.\exif-java\camera-zoom-moon-1.06' copied to '.\grouping\group-3\camera-zoom-moon-1.06' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 122: Cameringo-Lite.-Filters-Camera-3.0.0-------------------
# .\exif-java\Cameringo-Lite.-Filters-Camera-3.0.0
# Directory '.\exif-java\Cameringo-Lite.-Filters-Camera-3.0.0' copied to '.\grouping\group-3\Cameringo-Lite.-Filters-Camera-3.0.0' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 123: Candy-Camera-2019-7.7-------------------
# .\exif-java\Candy-Camera-2019-7.7
# Directory '.\exif-java\Candy-Camera-2019-7.7' copied to '.\grouping\group-1\Candy-Camera-2019-7.7' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 124: Candy-Camera-Selfie-2018-2.0-------------------
# .\exif-java\Candy-Camera-Selfie-2018-2.0
# Directory '.\exif-java\Candy-Camera-Selfie-2018-2.0' copied to '.\grouping\group-3\Candy-Camera-Selfie-2018-2.0' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 125: Candy-Camera-Sweat-2018-1.0-------------------
# .\exif-java\Candy-Camera-Sweat-2018-1.0
# Directory '.\exif-java\Candy-Camera-Sweat-2018-1.0' copied to '.\grouping\group-1\Candy-Camera-Sweat-2018-1.0' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 126: Candy-Gallery-v8.0.0.031-------------------
# .\exif-java\Candy-Gallery-v8.0.0.031
# Directory '.\exif-java\Candy-Gallery-v8.0.0.031' copied to '.\grouping\group-3\Candy-Gallery-v8.0.0.031' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 127: CandyCamera-6.0.89-play-------------------
# .\exif-java\CandyCamera-6.0.89-play
# Directory '.\exif-java\CandyCamera-6.0.89-play' copied to '.\grouping\group-1\CandyCamera-6.0.89-play' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 128: Carousel-Dropbox-Photos-1.15.3-------------------
# .\exif-java\Carousel-Dropbox-Photos-1.15.3
# Directory '.\exif-java\Carousel-Dropbox-Photos-1.15.3' copied to '.\grouping\group-3\Carousel-Dropbox-Photos-1.15.3' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 129: celebrate-share-photo-video-21.4.1-------------------
# .\exif-java\celebrate-share-photo-video-21.4.1
# Directory '.\exif-java\celebrate-share-photo-video-21.4.1' copied to '.\grouping\group-1\celebrate-share-photo-video-21.4.1' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 130: Cinema-4K-2.4.4-------------------
# .\exif-java\Cinema-4K-2.4.4
# Directory '.\exif-java\Cinema-4K-2.4.4' copied to '.\grouping\group-3\Cinema-4K-2.4.4' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 131: Cinema-FV-5-Lite-1.33-------------------
# .\exif-java\Cinema-FV-5-Lite-1.33
# Directory '.\exif-java\Cinema-FV-5-Lite-1.33' copied to '.\grouping\group-3\Cinema-FV-5-Lite-1.33' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 132: Cinema-FV-5-Pro-4.0-------------------
# .\exif-java\Cinema-FV-5-Pro-4.0
# Directory '.\exif-java\Cinema-FV-5-Pro-4.0' copied to '.\grouping\group-1\Cinema-FV-5-Pro-4.0' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 133: Clock-Vault-Hide-Photos-Videos-29.0-------------------
# .\exif-java\Clock-Vault-Hide-Photos-Videos-29.0
# Directory '.\exif-java\Clock-Vault-Hide-Photos-Videos-29.0' copied to '.\grouping\group-2\Clock-Vault-Hide-Photos-Videos-29.0' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 134: CM-FILE-MANAGER-2.7.8-------------------
# .\exif-java\CM-FILE-MANAGER-2.7.8
# Directory '.\exif-java\CM-FILE-MANAGER-2.7.8' copied to '.\grouping\group-3\CM-FILE-MANAGER-2.7.8' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 135: Collage-Maker-Photo-Editor-1.6.0-------------------
# .\exif-java\Collage-Maker-Photo-Editor-1.6.0
# Directory '.\exif-java\Collage-Maker-Photo-Editor-1.6.0' copied to '.\grouping\group-1\Collage-Maker-Photo-Editor-1.6.0' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 136: Color-Camera-Kawaii-Photo-Beauty-Plus-Cam-3.7.8-------------------
# .\exif-java\Color-Camera-Kawaii-Photo-Beauty-Plus-Cam-3.7.8
# Directory '.\exif-java\Color-Camera-Kawaii-Photo-Beauty-Plus-Cam-3.7.8' copied to '.\grouping\group-1\Color-Camera-Kawaii-Photo-Beauty-Plus-Cam-3.7.8' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 137: Colorize-Images-4.0.36-------------------
# .\exif-java\Colorize-Images-4.0.36
# Directory '.\exif-java\Colorize-Images-4.0.36' copied to '.\grouping\group-2\Colorize-Images-4.0.36' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 138: Colorrr-AI-Color-Old-Photos-1.1.1-------------------
# .\exif-java\Colorrr-AI-Color-Old-Photos-1.1.1
# Directory '.\exif-java\Colorrr-AI-Color-Old-Photos-1.1.1' copied to '.\grouping\group-2\Colorrr-AI-Color-Old-Photos-1.1.1' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 139: ComicMe-comics-photo-editor-1.0.24-------------------
# .\exif-java\ComicMe-comics-photo-editor-1.0.24
# Directory '.\exif-java\ComicMe-comics-photo-editor-1.0.24' copied to '.\grouping\group-3\ComicMe-comics-photo-editor-1.0.24' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 140: Compress-image-size-in-kb-mb-10-------------------
# .\exif-java\Compress-image-size-in-kb-mb-10
# Directory '.\exif-java\Compress-image-size-in-kb-mb-10' copied to '.\grouping\group-2\Compress-image-size-in-kb-mb-10' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 141: Cool-Mi-Camera-MIUI-12-Camera-4.5-------------------
# .\exif-java\Cool-Mi-Camera-MIUI-12-Camera-4.5
# Directory '.\exif-java\Cool-Mi-Camera-MIUI-12-Camera-4.5' copied to '.\grouping\group-2\Cool-Mi-Camera-MIUI-12-Camera-4.5' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 142: Cool-OS13-Camera-i-OS13-cam-4.3-------------------
# .\exif-java\Cool-OS13-Camera-i-OS13-cam-4.3
# Directory '.\exif-java\Cool-OS13-Camera-i-OS13-cam-4.3' copied to '.\grouping\group-2\Cool-OS13-Camera-i-OS13-cam-4.3' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 143: Cool-Photo-Editor-Camera-4.5-------------------
# .\exif-java\Cool-Photo-Editor-Camera-4.5
# Directory '.\exif-java\Cool-Photo-Editor-Camera-4.5' copied to '.\grouping\group-2\Cool-Photo-Editor-Camera-4.5' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 144: Cool-S20-Camera-Galaxy-S20-cam-3.1-------------------
# .\exif-java\Cool-S20-Camera-Galaxy-S20-cam-3.1
# Directory '.\exif-java\Cool-S20-Camera-Galaxy-S20-cam-3.1' copied to '.\grouping\group-2\Cool-S20-Camera-Galaxy-S20-cam-3.1' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 145: Cortex-Camera-1.01-------------------
# .\exif-java\Cortex-Camera-1.01
# Directory '.\exif-java\Cortex-Camera-1.01' copied to '.\grouping\group-1\Cortex-Camera-1.01' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 146: Crop-n-Square-Easy-crop-images-into-a-square-2.0.17-------------------
# .\exif-java\Crop-n-Square-Easy-crop-images-into-a-square-2.0.17
# Directory '.\exif-java\Crop-n-Square-Easy-crop-images-into-a-square-2.0.17' copied to '.\grouping\group-3\Crop-n-Square-Easy-crop-images-into-a-square-2.0.17' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 147: Cute-Doggy-Face-Camera-1.0-------------------
# .\exif-java\Cute-Doggy-Face-Camera-1.0
# Directory '.\exif-java\Cute-Doggy-Face-Camera-1.0' copied to '.\grouping\group-1\Cute-Doggy-Face-Camera-1.0' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 148: Cx-File-Explorer-1.9.9-------------------
# .\exif-java\Cx-File-Explorer-1.9.9
# Directory '.\exif-java\Cx-File-Explorer-1.9.9' copied to '.\grouping\group-2\Cx-File-Explorer-1.9.9' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 149: Cymera-4.4.2-------------------
# .\exif-java\Cymera-4.4.2
# Directory '.\exif-java\Cymera-4.4.2' copied to '.\grouping\group-2\Cymera-4.4.2' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 150: DateCamera2-Auto-timestamp-1.4.4-------------------
# .\exif-java\DateCamera2-Auto-timestamp-1.4.4
# Directory '.\exif-java\DateCamera2-Auto-timestamp-1.4.4' copied to '.\grouping\group-3\DateCamera2-Auto-timestamp-1.4.4' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 151: DeepFace-AI-Face-Editor-2.03.04-------------------
# .\exif-java\DeepFace-AI-Face-Editor-2.03.04
# Directory '.\exif-java\DeepFace-AI-Face-Editor-2.03.04' copied to '.\grouping\group-2\DeepFace-AI-Face-Editor-2.03.04' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 152: DigiCam-6.0844-------------------
# .\exif-java\DigiCam-6.0844
# Directory '.\exif-java\DigiCam-6.0844' copied to '.\grouping\group-1\DigiCam-6.0844' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 153: DoMyShoot-Product-Photo-Shoot-8.9.0-------------------
# .\exif-java\DoMyShoot-Product-Photo-Shoot-8.9.0
# Directory '.\exif-java\DoMyShoot-Product-Photo-Shoot-8.9.0' copied to '.\grouping\group-1\DoMyShoot-Product-Photo-Shoot-8.9.0' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 154: Dropbox-330.2.2-------------------
# .\exif-java\Dropbox-330.2.2
# Directory '.\exif-java\Dropbox-330.2.2' copied to '.\grouping\group-3\Dropbox-330.2.2' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 155: DSLR-Camera-Photo-Video-Editor-8.0-------------------
# .\exif-java\DSLR-Camera-Photo-Video-Editor-8.0
# Directory '.\exif-java\DSLR-Camera-Photo-Video-Editor-8.0' copied to '.\grouping\group-1\DSLR-Camera-Photo-Video-Editor-8.0' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# ...
# -------------------Loop 547: Spark-Email-3.3.4-------------------
# .\exif-java\Spark-Email-3.3.4
# Directory '.\exif-java\Spark-Email-3.3.4' copied to '.\grouping\group-2\Spark-Email-3.3.4' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 548: Square-InPic-Photo-Editor-4.2.20-------------------
# .\exif-java\Square-InPic-Photo-Editor-4.2.20
# Directory '.\exif-java\Square-InPic-Photo-Editor-4.2.20' copied to '.\grouping\group-3\Square-InPic-Photo-Editor-4.2.20' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 549: SquareDroid-Full-Size-Photo-for-Instagram-and-DP-2.3.7-------------------
# .\exif-java\SquareDroid-Full-Size-Photo-for-Instagram-and-DP-2.3.7
# Directory '.\exif-java\SquareDroid-Full-Size-Photo-for-Instagram-and-DP-2.3.7' copied to '.\grouping\group-1\SquareDroid-Full-Size-Photo-for-Instagram-and-DP-2.3.7' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 550: SquareIt-0.7.3-------------------
# .\exif-java\SquareIt-0.7.3
# Directory '.\exif-java\SquareIt-0.7.3' copied to '.\grouping\group-3\SquareIt-0.7.3' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 551: Super-ZOOM-HD-Camera-3.2-------------------
# .\exif-java\Super-ZOOM-HD-Camera-3.2
# Directory '.\exif-java\Super-ZOOM-HD-Camera-3.2' copied to '.\grouping\group-2\Super-ZOOM-HD-Camera-3.2' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 552: SuperImage-1.4.0-------------------
# .\exif-java\SuperImage-1.4.0
# Directory '.\exif-java\SuperImage-1.4.0' copied to '.\grouping\group-3\SuperImage-1.4.0' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 553: Sweet-Selfie-2018-2.0-------------------
# .\exif-java\Sweet-Selfie-2018-2.0
# Directory '.\exif-java\Sweet-Selfie-2018-2.0' copied to '.\grouping\group-3\Sweet-Selfie-2018-2.0' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 554: Sweetgram-Filter-effect-in-trendy-style-1.0-------------------
# .\exif-java\Sweetgram-Filter-effect-in-trendy-style-1.0
# Directory '.\exif-java\Sweetgram-Filter-effect-in-trendy-style-1.0' copied to '.\grouping\group-1\Sweetgram-Filter-effect-in-trendy-style-1.0' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 555: Teen-Cam-Photo-Sharing-6.0-------------------
# .\exif-java\Teen-Cam-Photo-Sharing-6.0
# Directory '.\exif-java\Teen-Cam-Photo-Sharing-6.0' copied to '.\grouping\group-1\Teen-Cam-Photo-Sharing-6.0' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 556: Teo-Teal-and-Orange-Filters-3.1.1-------------------
# .\exif-java\Teo-Teal-and-Orange-Filters-3.1.1
# Directory '.\exif-java\Teo-Teal-and-Orange-Filters-3.1.1' copied to '.\grouping\group-3\Teo-Teal-and-Orange-Filters-3.1.1' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 557: Thug-Life-Sticker-Pic-Editor-4.5.466-------------------
# .\exif-java\Thug-Life-Sticker-Pic-Editor-4.5.466
# Directory '.\exif-java\Thug-Life-Sticker-Pic-Editor-4.5.466' copied to '.\grouping\group-1\Thug-Life-Sticker-Pic-Editor-4.5.466' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 558: Timer-Camera-20.20.50-------------------
# .\exif-java\Timer-Camera-20.20.50
# Directory '.\exif-java\Timer-Camera-20.20.50' copied to '.\grouping\group-2\Timer-Camera-20.20.50' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 559: Timestamp-Camera-1.218-------------------
# .\exif-java\Timestamp-Camera-1.218
# Directory '.\exif-java\Timestamp-Camera-1.218' copied to '.\grouping\group-3\Timestamp-Camera-1.218' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 560: TimeStamp-Camera-1.6.5-------------------
# .\exif-java\TimeStamp-Camera-1.6.5
# Directory '.\exif-java\TimeStamp-Camera-1.6.5' copied to '.\grouping\group-3\TimeStamp-Camera-1.6.5' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 561: Timestamp-camera-1.7.12-------------------
# .\exif-java\Timestamp-camera-1.7.12
# Directory '.\exif-java\Timestamp-camera-1.7.12' copied to '.\grouping\group-1\Timestamp-camera-1.7.12' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 562: Timestamp-camera-Date-stamp-1.3-------------------
# .\exif-java\Timestamp-camera-Date-stamp-1.3
# Directory '.\exif-java\Timestamp-camera-Date-stamp-1.3' copied to '.\grouping\group-2\Timestamp-camera-Date-stamp-1.3' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 563: Timestamp-Camera-Date-Time-2.1-------------------
# .\exif-java\Timestamp-Camera-Date-Time-2.1
# Directory '.\exif-java\Timestamp-Camera-Date-Time-2.1' copied to '.\grouping\group-1\Timestamp-Camera-Date-Time-2.1' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 564: Tiny-Png-Image-Compressor-3.0-------------------
# .\exif-java\Tiny-Png-Image-Compressor-3.0
# Directory '.\exif-java\Tiny-Png-Image-Compressor-3.0' copied to '.\grouping\group-3\Tiny-Png-Image-Compressor-3.0' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 565: Tinypng-1.1-------------------
# .\exif-java\Tinypng-1.1
# Directory '.\exif-java\Tinypng-1.1' copied to '.\grouping\group-3\Tinypng-1.1' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 566: ToonMe-cartoon-yourself-sketch-dollify-maker-0.9.3-------------------
# .\exif-java\ToonMe-cartoon-yourself-sketch-dollify-maker-0.9.3
# Directory '.\exif-java\ToonMe-cartoon-yourself-sketch-dollify-maker-0.9.3' copied to '.\grouping\group-2\ToonMe-cartoon-yourself-sketch-dollify-maker-0.9.3' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 567: Total-Commander-3.42d-------------------
# .\exif-java\Total-Commander-3.42d
# Directory '.\exif-java\Total-Commander-3.42d' copied to '.\grouping\group-3\Total-Commander-3.42d' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 568: Touch-Retouch-Remove-Content-from-Photo-1.0.0-------------------
# .\exif-java\Touch-Retouch-Remove-Content-from-Photo-1.0.0
# Directory '.\exif-java\Touch-Retouch-Remove-Content-from-Photo-1.0.0' copied to '.\grouping\group-1\Touch-Retouch-Remove-Content-from-Photo-1.0.0' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 569: TPS-Mobile-5.0-------------------
# .\exif-java\TPS-Mobile-5.0
# Directory '.\exif-java\TPS-Mobile-5.0' copied to '.\grouping\group-2\TPS-Mobile-5.0' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 570: Triple-Camera-48-HD-X-Camera-2019-1.1-------------------
# .\exif-java\Triple-Camera-48-HD-X-Camera-2019-1.1
# Directory '.\exif-java\Triple-Camera-48-HD-X-Camera-2019-1.1' copied to '.\grouping\group-1\Triple-Camera-48-HD-X-Camera-2019-1.1' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 571: Triple-Camera-For-Samsung-Galaxy-A7-new-2019-230.05.25-------------------
# .\exif-java\Triple-Camera-For-Samsung-Galaxy-A7-new-2019-230.05.25
# Directory '.\exif-java\Triple-Camera-For-Samsung-Galaxy-A7-new-2019-230.05.25' copied to '.\grouping\group-1\Triple-Camera-For-Samsung-Galaxy-A7-new-2019-230.05.25' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 572: UHD-DSLR-Camera-4k-1.6.2-------------------
# .\exif-java\UHD-DSLR-Camera-4k-1.6.2
# Directory '.\exif-java\UHD-DSLR-Camera-4k-1.6.2' copied to '.\grouping\group-1\UHD-DSLR-Camera-4k-1.6.2' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 573: ULTRA-HD-CAMERA-4K-11.1-------------------
# .\exif-java\ULTRA-HD-CAMERA-4K-11.1
# Directory '.\exif-java\ULTRA-HD-CAMERA-4K-11.1' copied to '.\grouping\group-1\ULTRA-HD-CAMERA-4K-11.1' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 574: VASE-CAMERA-IRIS-PHOTO-EDITOR-5.02-------------------
# .\exif-java\VASE-CAMERA-IRIS-PHOTO-EDITOR-5.02
# Directory '.\exif-java\VASE-CAMERA-IRIS-PHOTO-EDITOR-5.02' copied to '.\grouping\group-1\VASE-CAMERA-IRIS-PHOTO-EDITOR-5.02' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 575: VASE-CAMERA-TULIP-PHOTO-EDITOR-2.02-------------------
# .\exif-java\VASE-CAMERA-TULIP-PHOTO-EDITOR-2.02
# Directory '.\exif-java\VASE-CAMERA-TULIP-PHOTO-EDITOR-2.02' copied to '.\grouping\group-1\VASE-CAMERA-TULIP-PHOTO-EDITOR-2.02' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 576: Vaulty-23.07.40-release-------------------
# .\exif-java\Vaulty-23.07.40-release
# Directory '.\exif-java\Vaulty-23.07.40-release' copied to '.\grouping\group-3\Vaulty-23.07.40-release' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 577: Verizon-Capture-3.2.0-------------------
# .\exif-java\Verizon-Capture-3.2.0
# Directory '.\exif-java\Verizon-Capture-3.2.0' copied to '.\grouping\group-2\Verizon-Capture-3.2.0' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 578: Vertical-Gallery-1.8.1-------------------
# .\exif-java\Vertical-Gallery-1.8.1
# Directory '.\exif-java\Vertical-Gallery-1.8.1' copied to '.\grouping\group-3\Vertical-Gallery-1.8.1' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 579: Vinci-AI-photo-filters-2.3-------------------
# .\exif-java\Vinci-AI-photo-filters-2.3
# Directory '.\exif-java\Vinci-AI-photo-filters-2.3' copied to '.\grouping\group-1\Vinci-AI-photo-filters-2.3' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 580: Vintage-Disposable-Camera-1.0.4-------------------
# .\exif-java\Vintage-Disposable-Camera-1.0.4
# Directory '.\exif-java\Vintage-Disposable-Camera-1.0.4' copied to '.\grouping\group-1\Vintage-Disposable-Camera-1.0.4' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 581: Vivid-AI-Photo-Enhancer-1.6.7-------------------
# .\exif-java\Vivid-AI-Photo-Enhancer-1.6.7
# Directory '.\exif-java\Vivid-AI-Photo-Enhancer-1.6.7' copied to '.\grouping\group-1\Vivid-AI-Photo-Enhancer-1.6.7' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 582: VSCO-323-------------------
# .\exif-java\VSCO-323
# Directory '.\exif-java\VSCO-323' copied to '.\grouping\group-1\VSCO-323' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 583: Watermark-Stamp-Text-on-Photo-1.3.3-------------------
# .\exif-java\Watermark-Stamp-Text-on-Photo-1.3.3
# Directory '.\exif-java\Watermark-Stamp-Text-on-Photo-1.3.3' copied to '.\grouping\group-2\Watermark-Stamp-Text-on-Photo-1.3.3' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 584: Wecam-selfie-retouch-edit-1.0.4214-------------------
# .\exif-java\Wecam-selfie-retouch-edit-1.0.4214
# Directory '.\exif-java\Wecam-selfie-retouch-edit-1.0.4214' copied to '.\grouping\group-3\Wecam-selfie-retouch-edit-1.0.4214' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 585: Whistle-Camera-Selfie-More-1.5.0-------------------
# .\exif-java\Whistle-Camera-Selfie-More-1.5.0
# Directory '.\exif-java\Whistle-Camera-Selfie-More-1.5.0' copied to '.\grouping\group-1\Whistle-Camera-Selfie-More-1.5.0' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 586: Wondershare-PowerCam-3.1.9.210422-------------------
# .\exif-java\Wondershare-PowerCam-3.1.9.210422
# Directory '.\exif-java\Wondershare-PowerCam-3.1.9.210422' copied to '.\grouping\group-3\Wondershare-PowerCam-3.1.9.210422' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 587: World-Painter-2.0-------------------
# .\exif-java\World-Painter-2.0
# Directory '.\exif-java\World-Painter-2.0' copied to '.\grouping\group-3\World-Painter-2.0' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 588: X-plore-4.31.03-------------------
# .\exif-java\X-plore-4.31.03
# Directory '.\exif-java\X-plore-4.31.03' copied to '.\grouping\group-3\X-plore-4.31.03' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 589: Xender-13.0.0.Prime-------------------
# .\exif-java\Xender-13.0.0.Prime
# Directory '.\exif-java\Xender-13.0.0.Prime' copied to '.\grouping\group-2\Xender-13.0.0.Prime' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 590: Yahoo-Mail-7.21.1-------------------
# .\exif-java\Yahoo-Mail-7.21.1
# Directory '.\exif-java\Yahoo-Mail-7.21.1' copied to '.\grouping\group-1\Yahoo-Mail-7.21.1' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 591: Yahoo-Mail-Go-Organized-Email-7.8.0-------------------
# .\exif-java\Yahoo-Mail-Go-Organized-Email-7.8.0
# Directory '.\exif-java\Yahoo-Mail-Go-Organized-Email-7.8.0' copied to '.\grouping\group-1\Yahoo-Mail-Go-Organized-Email-7.8.0' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 592: Yandex-Mail_8.60.3-------------------
# .\exif-java\Yandex-Mail_8.60.3
# Directory '.\exif-java\Yandex-Mail_8.60.3' copied to '.\grouping\group-3\Yandex-Mail_8.60.3' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 593: YI-Action-Camera-3.9.4-------------------
# .\exif-java\YI-Action-Camera-3.9.4
# Directory '.\exif-java\YI-Action-Camera-3.9.4' copied to '.\grouping\group-1\YI-Action-Camera-3.9.4' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 594: YouCam-Makeup-6.8.2-------------------
# .\exif-java\YouCam-Makeup-6.8.2
# Directory '.\exif-java\YouCam-Makeup-6.8.2' copied to '.\grouping\group-2\YouCam-Makeup-6.8.2' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 595: YouCam-Perfect-5.82.1-------------------
# .\exif-java\YouCam-Perfect-5.82.1
# Directory '.\exif-java\YouCam-Perfect-5.82.1' copied to '.\grouping\group-3\YouCam-Perfect-5.82.1' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 596: YouPic-2.3-------------------
# .\exif-java\YouPic-2.3
# Directory '.\exif-java\YouPic-2.3' copied to '.\grouping\group-1\YouPic-2.3' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 597: Z-Beauty-Camera-1.35-------------------
# .\exif-java\Z-Beauty-Camera-1.35
# Directory '.\exif-java\Z-Beauty-Camera-1.35' copied to '.\grouping\group-1\Z-Beauty-Camera-1.35' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 598: Z-Camera-Photo-Editor-Beauty-Selfie-Collage-4.60-------------------
# .\exif-java\Z-Camera-Photo-Editor-Beauty-Selfie-Collage-4.60
# Directory '.\exif-java\Z-Camera-Photo-Editor-Beauty-Selfie-Collage-4.60' copied to '.\grouping\group-1\Z-Camera-Photo-Editor-Beauty-Selfie-Collage-4.60' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 599: Z-Camera-PRO-30.04.24-------------------
# .\exif-java\Z-Camera-PRO-30.04.24
# Directory '.\exif-java\Z-Camera-PRO-30.04.24' copied to '.\grouping\group-1\Z-Camera-PRO-30.04.24' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
# -------------------Loop 600: ZArchiver-1.0.7-------------------
# .\exif-java\ZArchiver-1.0.7
# Directory '.\exif-java\ZArchiver-1.0.7' copied to '.\grouping\group-3\ZArchiver-1.0.7' successfully.
# CSV file 'paper_report_intent.csv' updated successfully.
