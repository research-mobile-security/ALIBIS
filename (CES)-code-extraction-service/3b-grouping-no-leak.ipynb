# %% [markdown]
# # GROUPING SOURCE CODE NO LEAK

# %%
import os
import shutil
import pandas as pd

# %% [markdown]
# ## 1. FUNCTION

# %%
# Function get directory
def get_all_directories(path):
    directories = []
    for entry in os.listdir(path):
        full_path = os.path.join(path, entry)
        if os.path.isdir(full_path):
            directories.append(entry)
    return directories
# Get all file in directory
def get_all_files_in_directory(directory_path):
    # Initialize an empty list to store file names
    file_list = []

    # Iterate through all files and directories in the specified directory
    for item in os.listdir(directory_path):
        # Construct the full path of the item
        full_path = os.path.join(directory_path, item)

        # Check if the item is a file (not a directory)
        if os.path.isfile(full_path):
            # Add the file to the list
            file_list.append(full_path)
    return file_list
# Function search file path that contain keywork
def find_files_with_keyword(directory, keyword):
    matching_files = []
    for root, _, files in os.walk(directory):
        for file in files:
            file_path = os.path.join(root, file)
            try:
                with open(file_path, 'r', encoding='utf-8') as f:
                    content = f.read()
                    if keyword in content:
                        matching_files.append(file_path)
            except Exception as e:
                print(f"Error reading {file_path}: {e}")
    return matching_files
# Function copy directory
def copy_directory(src_dir, dest_dir):
    try:
        # Copy the entire directory tree recursively
        shutil.copytree(src_dir, dest_dir)
        print(f"Directory '{src_dir}' copied to '{dest_dir}' successfully.")
    except FileExistsError:
        print(f"Directory '{dest_dir}' already exists.")
    except Exception as e:
        print(f"An error occurred: {e}")
# Update CSV
def update_csv_group(csv_file, apkfile_name, group):
    try:
        # Read the CSV file into a DataFrame
        df = pd.read_csv(csv_file)
        
        # Update the "exif_file_no" column where "apkfile_name" matches the given value
        df.loc[df['apkfile_name'] == apkfile_name, 'group'] = int(group)
        
        # Write the updated DataFrame back to the CSV file
        df.to_csv(csv_file, index=False)
        
        print(f"CSV file '{csv_file}' updated successfully.")
    except FileNotFoundError:
        print("CSV file not found.")
    except Exception as e:
        print(f"An error occurred while updating the CSV file: {e}")

# %% [markdown]
# ## 2. STATIC VARIABLE

# %%
exif_java_directory = r".\exif-java-no-leak"
csv_file = "no_leak_apk_low_size.csv"
group_1 = r".\grouping-no-leak\group-1-no-leak"
group_2 = r".\grouping-no-leak\group-2-no-leak"
group_3 = r".\grouping-no-leak\group-3-no-leak"

# %% [markdown]
# ## 3. MAIN

# %%
directories = get_all_directories(exif_java_directory)
for i in range(len(directories)):
    print("-------------------Loop "+str(i)+": "+str(directories[i])+"-------------------")
    src_directory = exif_java_directory+"\\"+directories[i]
    print(src_directory)
    apkfile_name = directories[i]+".apk"
    if(len(find_files_with_keyword(src_directory, "android.media.ExifInterface"))>0):
        copy_directory(src_directory, group_1+"\\"+directories[i])
        update_csv_group(csv_file, apkfile_name, 1)
    elif(len(find_files_with_keyword(src_directory, "androidx.exifinterface.media"))>0):
        copy_directory(src_directory, group_2+"\\"+directories[i])
        update_csv_group(csv_file, apkfile_name, 2)
    else:
        copy_directory(src_directory, group_3+"\\"+directories[i])
        update_csv_group(csv_file, apkfile_name, 3)
# Out:
# -------------------Loop 0: 14-August-Photo-Frame-2023-13.3-------------------
# .\exif-java-no-leak\14-August-Photo-Frame-2023-13.3
# Directory '.\grouping-no-leak\group-3-no-leak\14-August-Photo-Frame-2023-13.3' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 1: 14-August-Photo-Frame-Sticker-13.1-------------------
# .\exif-java-no-leak\14-August-Photo-Frame-Sticker-13.1
# Directory '.\grouping-no-leak\group-3-no-leak\14-August-Photo-Frame-Sticker-13.1' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 2: 1967-Cam-Vintage-Filters-1.0-------------------
# .\exif-java-no-leak\1967-Cam-Vintage-Filters-1.0
# Directory '.\grouping-no-leak\group-1-no-leak\1967-Cam-Vintage-Filters-1.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 3: 20k-Wallpaper-1.0-------------------
# .\exif-java-no-leak\20k-Wallpaper-1.0
# Directory '.\grouping-no-leak\group-3-no-leak\20k-Wallpaper-1.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 4: 21-Savage-Rapper-Wallpaper-HD-1.0-------------------
# .\exif-java-no-leak\21-Savage-Rapper-Wallpaper-HD-1.0
# Directory '.\grouping-no-leak\group-1-no-leak\21-Savage-Rapper-Wallpaper-HD-1.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 5: 3D-Gallery-Smart-Gallery-1.2.123-------------------
# .\exif-java-no-leak\3D-Gallery-Smart-Gallery-1.2.123
# Directory '.\grouping-no-leak\group-1-no-leak\3D-Gallery-Smart-Gallery-1.2.123' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 6: 48-Yoo-Seung-Ho-Wallpaper-HD-1.0.42-------------------
# .\exif-java-no-leak\48-Yoo-Seung-Ho-Wallpaper-HD-1.0.42
# Directory '.\grouping-no-leak\group-3-no-leak\48-Yoo-Seung-Ho-Wallpaper-HD-1.0.42' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 7: 500-Firepaper-3.00-------------------
# .\exif-java-no-leak\500-Firepaper-3.00
# Directory '.\grouping-no-leak\group-3-no-leak\500-Firepaper-3.00' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 8: 8BitMe-1.5-------------------
# .\exif-java-no-leak\8BitMe-1.5
# Directory '.\grouping-no-leak\group-3-no-leak\8BitMe-1.5' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 9: 8mm-Vintage-Camera-Advice-3.3-------------------
# .\exif-java-no-leak\8mm-Vintage-Camera-Advice-3.3
# Directory '.\grouping-no-leak\group-3-no-leak\8mm-Vintage-Camera-Advice-3.3' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 10: 9-square-insta-grid-photo-for-Instagram-0.0.3-------------------
# .\exif-java-no-leak\9-square-insta-grid-photo-for-Instagram-0.0.3
# Directory '.\grouping-no-leak\group-1-no-leak\9-square-insta-grid-photo-for-Instagram-0.0.3' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 11: 9square-4.00.08-------------------
# .\exif-java-no-leak\9square-4.00.08
# Directory '.\grouping-no-leak\group-3-no-leak\9square-4.00.08' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 12: A-Photo-Manager-0.8.3.200315-------------------
# .\exif-java-no-leak\A-Photo-Manager-0.8.3.200315
# Directory '.\grouping-no-leak\group-1-no-leak\A-Photo-Manager-0.8.3.200315' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 13: A9-Data-Collection-1.7-------------------
# .\exif-java-no-leak\A9-Data-Collection-1.7
# Directory '.\grouping-no-leak\group-1-no-leak\A9-Data-Collection-1.7' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 14: Action-Snap-2.5-------------------
# .\exif-java-no-leak\Action-Snap-2.5
# Directory '.\grouping-no-leak\group-3-no-leak\Action-Snap-2.5' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 15: ADD-Accessories-To-Your-Photo-1.1-------------------
# .\exif-java-no-leak\ADD-Accessories-To-Your-Photo-1.1
# Directory '.\grouping-no-leak\group-1-no-leak\ADD-Accessories-To-Your-Photo-1.1' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 16: Adobe-Color-CC-1.3-------------------
# .\exif-java-no-leak\Adobe-Color-CC-1.3
# Directory '.\grouping-no-leak\group-1-no-leak\Adobe-Color-CC-1.3' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 17: Aesth-Aesthetic-editor-lom-1.0.2-------------------
# .\exif-java-no-leak\Aesth-Aesthetic-editor-lom-1.0.2
# Directory '.\grouping-no-leak\group-3-no-leak\Aesth-Aesthetic-editor-lom-1.0.2' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 18: Alice-Angel-Bendy-Ink-Funny-FaceMaker-1.0-------------------
# .\exif-java-no-leak\Alice-Angel-Bendy-Ink-Funny-FaceMaker-1.0
# Directory '.\grouping-no-leak\group-3-no-leak\Alice-Angel-Bendy-Ink-Funny-FaceMaker-1.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 19: All-Photo-Frames-2023-1.0.34-------------------
# .\exif-java-no-leak\All-Photo-Frames-2023-1.0.34
# Directory '.\grouping-no-leak\group-2-no-leak\All-Photo-Frames-2023-1.0.34' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 20: All-Songs-The-Greatest-Showman-1.0.0-------------------
# .\exif-java-no-leak\All-Songs-The-Greatest-Showman-1.0.0
# Directory '.\grouping-no-leak\group-3-no-leak\All-Songs-The-Greatest-Showman-1.0.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 21: Ambedkar-Photo-Editor-1.1.27-------------------
# .\exif-java-no-leak\Ambedkar-Photo-Editor-1.1.27
# Directory '.\grouping-no-leak\group-3-no-leak\Ambedkar-Photo-Editor-1.1.27' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 22: American-Football-Wallpaper-4K-Ultra-HD-1.0.5-------------------
# .\exif-java-no-leak\American-Football-Wallpaper-4K-Ultra-HD-1.0.5
# Directory '.\grouping-no-leak\group-3-no-leak\American-Football-Wallpaper-4K-Ultra-HD-1.0.5' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 23: Angel-Wings-Photo-Effect-1.2-------------------
# .\exif-java-no-leak\Angel-Wings-Photo-Effect-1.2
# Directory '.\grouping-no-leak\group-3-no-leak\Angel-Wings-Photo-Effect-1.2' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 24: Animal-Face-Selfie-Camera-1.0-------------------
# .\exif-java-no-leak\Animal-Face-Selfie-Camera-1.0
# Directory '.\grouping-no-leak\group-3-no-leak\Animal-Face-Selfie-Camera-1.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 25: Anime-Voice-Changer-1.1-------------------
# .\exif-java-no-leak\Anime-Voice-Changer-1.1
# Directory '.\grouping-no-leak\group-3-no-leak\Anime-Voice-Changer-1.1' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 26: Anytime-Gallery-for-Wear-4.0-------------------
# .\exif-java-no-leak\Anytime-Gallery-for-Wear-4.0
# Directory '.\grouping-no-leak\group-3-no-leak\Anytime-Gallery-for-Wear-4.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 27: APD-TimeStamp-1.6.1-------------------
# .\exif-java-no-leak\APD-TimeStamp-1.6.1
# Directory '.\grouping-no-leak\group-3-no-leak\APD-TimeStamp-1.6.1' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 28: APNG-Maker-1.0.8-------------------
# .\exif-java-no-leak\APNG-Maker-1.0.8
# Directory '.\grouping-no-leak\group-3-no-leak\APNG-Maker-1.0.8' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 29: AR-Photo-Editor-Jarvis-Holog-1.7.2-------------------
# .\exif-java-no-leak\AR-Photo-Editor-Jarvis-Holog-1.7.2
# Directory '.\grouping-no-leak\group-3-no-leak\AR-Photo-Editor-Jarvis-Holog-1.7.2' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 30: Arab-Men-Dress-Photo-Editor-1.8-------------------
# .\exif-java-no-leak\Arab-Men-Dress-Photo-Editor-1.8
# Directory '.\grouping-no-leak\group-3-no-leak\Arab-Men-Dress-Photo-Editor-1.8' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 31: art-filter-art-filter-photo-editor-1.2-------------------
# .\exif-java-no-leak\art-filter-art-filter-photo-editor-1.2
# Directory '.\grouping-no-leak\group-3-no-leak\art-filter-art-filter-photo-editor-1.2' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 32: Ashi-Singh-HD-Gallery-1.0.0-------------------
# .\exif-java-no-leak\Ashi-Singh-HD-Gallery-1.0.0
# Directory '.\grouping-no-leak\group-1-no-leak\Ashi-Singh-HD-Gallery-1.0.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 33: AThumb-Cut-2.05-------------------
# .\exif-java-no-leak\AThumb-Cut-2.05
# Directory '.\grouping-no-leak\group-1-no-leak\AThumb-Cut-2.05' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 34: Aura-Camera-2.0.0-------------------
# .\exif-java-no-leak\Aura-Camera-2.0.0
# Directory '.\grouping-no-leak\group-3-no-leak\Aura-Camera-2.0.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 35: Avril-Lavigne-Wallpaper-0.1-------------------
# .\exif-java-no-leak\Avril-Lavigne-Wallpaper-0.1
# Directory '.\grouping-no-leak\group-3-no-leak\Avril-Lavigne-Wallpaper-0.1' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 36: AZ-Camera-Manual-Pro-Cam-2.2-------------------
# .\exif-java-no-leak\AZ-Camera-Manual-Pro-Cam-2.2
# Directory '.\grouping-no-leak\group-1-no-leak\AZ-Camera-Manual-Pro-Cam-2.2' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 37: B12-Selfie-Camera-No-Crop-1.0.2-------------------
# .\exif-java-no-leak\B12-Selfie-Camera-No-Crop-1.0.2
# Directory '.\grouping-no-leak\group-1-no-leak\B12-Selfie-Camera-No-Crop-1.0.2' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 38: b621-selfie-camera-snappy-photo-Filter-Stickers-1.8-------------------
# .\exif-java-no-leak\b621-selfie-camera-snappy-photo-Filter-Stickers-1.8
# Directory '.\grouping-no-leak\group-1-no-leak\b621-selfie-camera-snappy-photo-Filter-Stickers-1.8' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 39: B812-Selfie-Camera-2.1-------------------
# .\exif-java-no-leak\B812-Selfie-Camera-2.1
# Directory '.\grouping-no-leak\group-1-no-leak\B812-Selfie-Camera-2.1' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 40: Baby-Birthday-Stickers-1.0-------------------
# .\exif-java-no-leak\Baby-Birthday-Stickers-1.0
# Directory '.\grouping-no-leak\group-1-no-leak\Baby-Birthday-Stickers-1.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 41: Baby-Photo-Art-Capture-Preci-2.2.0-------------------
# .\exif-java-no-leak\Baby-Photo-Art-Capture-Preci-2.2.0
# Directory '.\grouping-no-leak\group-1-no-leak\Baby-Photo-Art-Capture-Preci-2.2.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 42: Baby-Photo-Frames-Kids-1.2-------------------
# .\exif-java-no-leak\Baby-Photo-Frames-Kids-1.2
# Directory '.\grouping-no-leak\group-3-no-leak\Baby-Photo-Frames-Kids-1.2' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 43: Baby-Photo-Nice-Baby-wallpaper-1.7-------------------
# .\exif-java-no-leak\Baby-Photo-Nice-Baby-wallpaper-1.7
# Directory '.\grouping-no-leak\group-3-no-leak\Baby-Photo-Nice-Baby-wallpaper-1.7' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 44: Background-Eraser-Automatic-4.0.6-------------------
# .\exif-java-no-leak\Background-Eraser-Automatic-4.0.6
# Directory '.\grouping-no-leak\group-3-no-leak\Background-Eraser-Automatic-4.0.6' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 45: Background-Video-Camera-4.4.1-------------------
# .\exif-java-no-leak\Background-Video-Camera-4.4.1
# Directory '.\grouping-no-leak\group-3-no-leak\Background-Video-Camera-4.4.1' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 46: Background-Video-Recorder-2-7.0-------------------
# .\exif-java-no-leak\Background-Video-Recorder-2-7.0
# Directory '.\grouping-no-leak\group-3-no-leak\Background-Video-Recorder-2-7.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 47: background-video-recorder-3.15-------------------
# .\exif-java-no-leak\background-video-recorder-3.15
# Directory '.\grouping-no-leak\group-3-no-leak\background-video-recorder-3.15' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 48: Background-video-recording-camera-2.1.1-------------------
# .\exif-java-no-leak\Background-video-recording-camera-2.1.1
# Directory '.\grouping-no-leak\group-3-no-leak\Background-video-recording-camera-2.1.1' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 49: Baldis-Basics-in-Education-New-Wallpaper-1.1-------------------
# .\exif-java-no-leak\Baldis-Basics-in-Education-New-Wallpaper-1.1
# Directory '.\grouping-no-leak\group-1-no-leak\Baldis-Basics-in-Education-New-Wallpaper-1.1' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 50: Basketball-Photo-Editor-1.0-------------------
# .\exif-java-no-leak\Basketball-Photo-Editor-1.0
# Directory '.\grouping-no-leak\group-3-no-leak\Basketball-Photo-Editor-1.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 51: Bazaart-Photo-Editor-and-Design-1.0-------------------
# .\exif-java-no-leak\Bazaart-Photo-Editor-and-Design-1.0
# Directory '.\grouping-no-leak\group-3-no-leak\Bazaart-Photo-Editor-and-Design-1.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 52: Beach-Wallpaper-4K-Ultra-HD-1.0.5-------------------
# .\exif-java-no-leak\Beach-Wallpaper-4K-Ultra-HD-1.0.5
# Directory '.\grouping-no-leak\group-3-no-leak\Beach-Wallpaper-4K-Ultra-HD-1.0.5' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 53: Beautiful-Couples-Photo-Suit-1.7-------------------
# .\exif-java-no-leak\Beautiful-Couples-Photo-Suit-1.7
# Directory '.\grouping-no-leak\group-3-no-leak\Beautiful-Couples-Photo-Suit-1.7' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 54: Beauty-Camera-1.5-------------------
# .\exif-java-no-leak\Beauty-Camera-1.5
# Directory '.\grouping-no-leak\group-1-no-leak\Beauty-Camera-1.5' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 55: Best-Car-Wallpapers-HD-Cool-1.0-------------------
# .\exif-java-no-leak\Best-Car-Wallpapers-HD-Cool-1.0
# Directory '.\grouping-no-leak\group-3-no-leak\Best-Car-Wallpapers-HD-Cool-1.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 56: Best-FNAF-wallpaper-1.0-------------------
# .\exif-java-no-leak\Best-FNAF-wallpaper-1.0
# Directory '.\grouping-no-leak\group-1-no-leak\Best-FNAF-wallpaper-1.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 57: Best-Mortal-Wallpapers-Kombat-1.0.0-------------------
# .\exif-java-no-leak\Best-Mortal-Wallpapers-Kombat-1.0.0
# Directory '.\grouping-no-leak\group-1-no-leak\Best-Mortal-Wallpapers-Kombat-1.0.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 58: Best-Scream-Wallpaper-HD-1.1.0-------------------
# .\exif-java-no-leak\Best-Scream-Wallpaper-HD-1.1.0
# Directory '.\grouping-no-leak\group-1-no-leak\Best-Scream-Wallpaper-HD-1.1.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 59: Bestie-Love-Selfie-Camera-1.0-------------------
# .\exif-java-no-leak\Bestie-Love-Selfie-Camera-1.0
# Directory '.\grouping-no-leak\group-1-no-leak\Bestie-Love-Selfie-Camera-1.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 60: Big-Mouth-Camera-1.0-------------------
# .\exif-java-no-leak\Big-Mouth-Camera-1.0
# Directory '.\grouping-no-leak\group-3-no-leak\Big-Mouth-Camera-1.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 61: Big-Telescope-Zoom-HD-Camera-1.0.5-------------------
# .\exif-java-no-leak\Big-Telescope-Zoom-HD-Camera-1.0.5
# Directory '.\grouping-no-leak\group-1-no-leak\Big-Telescope-Zoom-HD-Camera-1.0.5' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 62: Billie-Eilish-Wallpaper-2020-HD-1.0.4-------------------
# .\exif-java-no-leak\Billie-Eilish-Wallpaper-2020-HD-1.0.4
# Directory '.\grouping-no-leak\group-1-no-leak\Billie-Eilish-Wallpaper-2020-HD-1.0.4' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 63: Binoculars-Model-V11-Zoom-Cam-1.0.5-------------------
# .\exif-java-no-leak\Binoculars-Model-V11-Zoom-Cam-1.0.5
# Directory '.\grouping-no-leak\group-3-no-leak\Binoculars-Model-V11-Zoom-Cam-1.0.5' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 64: Binoculars-Night-Mode-Zoom-1.7.4-------------------
# .\exif-java-no-leak\Binoculars-Night-Mode-Zoom-1.7.4
# Directory '.\grouping-no-leak\group-3-no-leak\Binoculars-Night-Mode-Zoom-1.7.4' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 65: Binoculars-X-C15-Photo-Video-1.1.6-------------------
# .\exif-java-no-leak\Binoculars-X-C15-Photo-Video-1.1.6
# Directory '.\grouping-no-leak\group-3-no-leak\Binoculars-X-C15-Photo-Video-1.1.6' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 66: Black-And-White-Photo-Editor-1.58-------------------
# .\exif-java-no-leak\Black-And-White-Photo-Editor-1.58
# Directory '.\grouping-no-leak\group-1-no-leak\Black-And-White-Photo-Editor-1.58' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 67: Black-Wallpaper-4K-Ultra-HD-1.0.5-------------------
# .\exif-java-no-leak\Black-Wallpaper-4K-Ultra-HD-1.0.5
# Directory '.\grouping-no-leak\group-3-no-leak\Black-Wallpaper-4K-Ultra-HD-1.0.5' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 68: Blend-Collage-2.4-------------------
# .\exif-java-no-leak\Blend-Collage-2.4
# Directory '.\grouping-no-leak\group-3-no-leak\Blend-Collage-2.4' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 69: Bluetooth-Remote-Shutter-1.1.3-------------------
# .\exif-java-no-leak\Bluetooth-Remote-Shutter-1.1.3
# Directory '.\grouping-no-leak\group-3-no-leak\Bluetooth-Remote-Shutter-1.1.3' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 70: Blur-4.1.0-------------------
# .\exif-java-no-leak\Blur-4.1.0
# Directory '.\grouping-no-leak\group-1-no-leak\Blur-4.1.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 71: Blur-and-Pixelate-1.0.7-------------------
# .\exif-java-no-leak\Blur-and-Pixelate-1.0.7
# Directory '.\grouping-no-leak\group-1-no-leak\Blur-and-Pixelate-1.0.7' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 72: Blur-Face-Censor-Image-1.0.6-------------------
# .\exif-java-no-leak\Blur-Face-Censor-Image-1.0.6
# Directory '.\grouping-no-leak\group-3-no-leak\Blur-Face-Censor-Image-1.0.6' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 73: Blur-Image-1.3.3-------------------
# .\exif-java-no-leak\Blur-Image-1.3.3
# Directory '.\grouping-no-leak\group-3-no-leak\Blur-Image-1.3.3' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 74: Blur-Image-Background-1.2-------------------
# .\exif-java-no-leak\Blur-Image-Background-1.2
# Directory '.\grouping-no-leak\group-1-no-leak\Blur-Image-Background-1.2' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 75: Blur-Photo-Editor-Background-38-------------------
# .\exif-java-no-leak\Blur-Photo-Editor-Background-38
# Directory '.\grouping-no-leak\group-2-no-leak\Blur-Photo-Editor-Background-38' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 76: BlurArt-Blur-Photo-Editor-2.5-------------------
# .\exif-java-no-leak\BlurArt-Blur-Photo-Editor-2.5
# Directory '.\grouping-no-leak\group-2-no-leak\BlurArt-Blur-Photo-Editor-2.5' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 77: Body-Shape-Photo-Editor-1.6-------------------
# .\exif-java-no-leak\Body-Shape-Photo-Editor-1.6
# Directory '.\grouping-no-leak\group-1-no-leak\Body-Shape-Photo-Editor-1.6' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 78: Boy-Sherwani-Photo-Suit-2.5-------------------
# .\exif-java-no-leak\Boy-Sherwani-Photo-Suit-2.5
# Directory '.\grouping-no-leak\group-2-no-leak\Boy-Sherwani-Photo-Suit-2.5' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 79: Braces-Camera-Photo-Booth-1.4-------------------
# .\exif-java-no-leak\Braces-Camera-Photo-Booth-1.4
# Directory '.\grouping-no-leak\group-1-no-leak\Braces-Camera-Photo-Booth-1.4' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 80: Braces-Photo-Editor-Free-5.0-------------------
# .\exif-java-no-leak\Braces-Photo-Editor-Free-5.0
# Directory '.\grouping-no-leak\group-1-no-leak\Braces-Photo-Editor-Free-5.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 81: Breaking-News-Video-Maker-2.8-------------------
# .\exif-java-no-leak\Breaking-News-Video-Maker-2.8
# Directory '.\grouping-no-leak\group-3-no-leak\Breaking-News-Video-Maker-2.8' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 82: Brilliance-500px-Image-Viewer-3-------------------
# .\exif-java-no-leak\Brilliance-500px-Image-Viewer-3
# Directory '.\grouping-no-leak\group-3-no-leak\Brilliance-500px-Image-Viewer-3' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 83: Bruised-Face-Fake-Injury-Photo-Editor-1.2-------------------
# .\exif-java-no-leak\Bruised-Face-Fake-Injury-Photo-Editor-1.2
# Directory '.\grouping-no-leak\group-1-no-leak\Bruised-Face-Fake-Injury-Photo-Editor-1.2' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 84: Brush-Stroke-1.1-------------------
# .\exif-java-no-leak\Brush-Stroke-1.1
# Directory '.\grouping-no-leak\group-1-no-leak\Brush-Stroke-1.1' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 85: BTS-Wallpaper-2021-1.0-------------------
# .\exif-java-no-leak\BTS-Wallpaper-2021-1.0
# Directory '.\grouping-no-leak\group-3-no-leak\BTS-Wallpaper-2021-1.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 86: BTS-Wallpapers-HD-1.0-------------------
# .\exif-java-no-leak\BTS-Wallpapers-HD-1.0
# Directory '.\grouping-no-leak\group-3-no-leak\BTS-Wallpapers-HD-1.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 87: Buenos-dias-Buenas-tardes-y-Buenas-noches-Gifs-4.0-------------------
# .\exif-java-no-leak\Buenos-dias-Buenas-tardes-y-Buenas-noches-Gifs-4.0
# Directory '.\grouping-no-leak\group-1-no-leak\Buenos-dias-Buenas-tardes-y-Buenas-noches-Gifs-4.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 88: Bullet-Bike-Photo-Editor-1.1-------------------
# .\exif-java-no-leak\Bullet-Bike-Photo-Editor-1.1
# Directory '.\grouping-no-leak\group-3-no-leak\Bullet-Bike-Photo-Editor-1.1' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 89: Buna-Dimineaa-Imagini-1.0-------------------
# .\exif-java-no-leak\Buna-Dimineaa-Imagini-1.0
# Directory '.\grouping-no-leak\group-3-no-leak\Buna-Dimineaa-Imagini-1.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 90: Burst-Mode-Camera-1.65-------------------
# .\exif-java-no-leak\Burst-Mode-Camera-1.65
# Directory '.\grouping-no-leak\group-3-no-leak\Burst-Mode-Camera-1.65' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 91: Butt-Cam-1.2-------------------
# .\exif-java-no-leak\Butt-Cam-1.2
# Directory '.\grouping-no-leak\group-3-no-leak\Butt-Cam-1.2' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 92: Call-of-Duty-Black-ops-4-wallpaper-1.0-------------------
# .\exif-java-no-leak\Call-of-Duty-Black-ops-4-wallpaper-1.0
# Directory '.\grouping-no-leak\group-3-no-leak\Call-of-Duty-Black-ops-4-wallpaper-1.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 93: Cam-Factory-34.0-------------------
# .\exif-java-no-leak\Cam-Factory-34.0
# Directory '.\grouping-no-leak\group-3-no-leak\Cam-Factory-34.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 94: Cam-Lab-1.0-------------------
# .\exif-java-no-leak\Cam-Lab-1.0
# Directory '.\grouping-no-leak\group-3-no-leak\Cam-Lab-1.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 95: Camera-Clash-Photo-Effects-1.3.6-------------------
# .\exif-java-no-leak\Camera-Clash-Photo-Effects-1.3.6
# Directory '.\grouping-no-leak\group-3-no-leak\Camera-Clash-Photo-Effects-1.3.6' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 96: Camera-Connect-Control-6.3.3-------------------
# .\exif-java-no-leak\Camera-Connect-Control-6.3.3
# Directory '.\grouping-no-leak\group-1-no-leak\Camera-Connect-Control-6.3.3' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 97: City-Hording-Photo-Frames-1.8-------------------
# .\exif-java-no-leak\City-Hording-Photo-Frames-1.8
# Directory '.\grouping-no-leak\group-2-no-leak\City-Hording-Photo-Frames-1.8' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 98: Cloud-Storage-3.9.6-------------------
# .\exif-java-no-leak\Cloud-Storage-3.9.6
# Directory '.\grouping-no-leak\group-3-no-leak\Cloud-Storage-3.9.6' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 99: Coffee-Cup-Dual-Photo-Frames-2.0.4-------------------
# .\exif-java-no-leak\Coffee-Cup-Dual-Photo-Frames-2.0.4
# Directory '.\grouping-no-leak\group-3-no-leak\Coffee-Cup-Dual-Photo-Frames-2.0.4' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 100: Color-Effect-Square-Photo-29.9.2-------------------
# .\exif-java-no-leak\Color-Effect-Square-Photo-29.9.2
# Directory '.\grouping-no-leak\group-3-no-leak\Color-Effect-Square-Photo-29.9.2' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 101: Color-Grab-color-detection-3.9.2-------------------
# .\exif-java-no-leak\Color-Grab-color-detection-3.9.2
# Directory '.\grouping-no-leak\group-3-no-leak\Color-Grab-color-detection-3.9.2' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 102: Colorize-Black-and-White-Photo-5-------------------
# .\exif-java-no-leak\Colorize-Black-and-White-Photo-5
# Directory '.\grouping-no-leak\group-1-no-leak\Colorize-Black-and-White-Photo-5' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 103: ColouriseSG-2.1-------------------
# .\exif-java-no-leak\ColouriseSG-2.1
# Directory '.\grouping-no-leak\group-3-no-leak\ColouriseSG-2.1' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 104: Convert-photo-to-drawing-1.1-------------------
# .\exif-java-no-leak\Convert-photo-to-drawing-1.1
# Directory '.\grouping-no-leak\group-1-no-leak\Convert-photo-to-drawing-1.1' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 105: Couple-Photo-Editor-2.4-------------------
# .\exif-java-no-leak\Couple-Photo-Editor-2.4
# Directory '.\grouping-no-leak\group-2-no-leak\Couple-Photo-Editor-2.4' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 106: Couple-Photo-Fashion-Frames-1.7-------------------
# .\exif-java-no-leak\Couple-Photo-Fashion-Frames-1.7
# Directory '.\grouping-no-leak\group-3-no-leak\Couple-Photo-Fashion-Frames-1.7' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 107: Couple-Photo-Mixer-Blender-1.4.13-------------------
# .\exif-java-no-leak\Couple-Photo-Mixer-Blender-1.4.13
# Directory '.\grouping-no-leak\group-2-no-leak\Couple-Photo-Mixer-Blender-1.4.13' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 108: Couple-Romantic-Photo-Montage-1.0.3-------------------
# .\exif-java-no-leak\Couple-Romantic-Photo-Montage-1.0.3
# Directory '.\grouping-no-leak\group-3-no-leak\Couple-Romantic-Photo-Montage-1.0.3' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 109: Couple-Wonderful-Photo-Suit-1.0.5-------------------
# .\exif-java-no-leak\Couple-Wonderful-Photo-Suit-1.0.5
# Directory '.\grouping-no-leak\group-3-no-leak\Couple-Wonderful-Photo-Suit-1.0.5' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 110: Couples-Photos-Design-Suits-1.0.6-------------------
# .\exif-java-no-leak\Couples-Photos-Design-Suits-1.0.6
# Directory '.\grouping-no-leak\group-3-no-leak\Couples-Photos-Design-Suits-1.0.6' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 111: CR7-Wallpaper-a.1.0-------------------
# .\exif-java-no-leak\CR7-Wallpaper-a.1.0
# Directory '.\grouping-no-leak\group-1-no-leak\CR7-Wallpaper-a.1.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 112: Crazy-Meme-Photo-Editor-Meme-Face-Stickers-1.0-------------------
# .\exif-java-no-leak\Crazy-Meme-Photo-Editor-Meme-Face-Stickers-1.0
# Directory '.\grouping-no-leak\group-3-no-leak\Crazy-Meme-Photo-Editor-Meme-Face-Stickers-1.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 113: Crop-Image-Resize-image-2.0.2-------------------
# .\exif-java-no-leak\Crop-Image-Resize-image-2.0.2
# Directory '.\grouping-no-leak\group-2-no-leak\Crop-Image-Resize-image-2.0.2' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 114: Cut-and-Paste-Photos-2.5.3-------------------
# .\exif-java-no-leak\Cut-and-Paste-Photos-2.5.3
# Directory '.\grouping-no-leak\group-3-no-leak\Cut-and-Paste-Photos-2.5.3' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 115: Cut-Paste-Photo-Editor-1.6-------------------
# .\exif-java-no-leak\Cut-Paste-Photo-Editor-1.6
# Directory '.\grouping-no-leak\group-1-no-leak\Cut-Paste-Photo-Editor-1.6' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 116: Cut-Paste-Photo-Seamless-Edit-34.2-------------------
# .\exif-java-no-leak\Cut-Paste-Photo-Seamless-Edit-34.2
# Directory '.\grouping-no-leak\group-1-no-leak\Cut-Paste-Photo-Seamless-Edit-34.2' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 117: Cute-Gudetama-and-Friends-Wallpaper-HD-1.0.0-------------------
# .\exif-java-no-leak\Cute-Gudetama-and-Friends-Wallpaper-HD-1.0.0
# Directory '.\grouping-no-leak\group-1-no-leak\Cute-Gudetama-and-Friends-Wallpaper-HD-1.0.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 118: Cute-Gudetama-Wallpaper-HD-1.0-------------------
# .\exif-java-no-leak\Cute-Gudetama-Wallpaper-HD-1.0
# Directory '.\grouping-no-leak\group-1-no-leak\Cute-Gudetama-Wallpaper-HD-1.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 119: Cute-Marshmallow-Wallpaper-HD-1.1.0-------------------
# .\exif-java-no-leak\Cute-Marshmallow-Wallpaper-HD-1.1.0
# Directory '.\grouping-no-leak\group-1-no-leak\Cute-Marshmallow-Wallpaper-HD-1.1.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 120: cute-pepe-snap-Sticker-emoji-2.0.3-------------------
# .\exif-java-no-leak\cute-pepe-snap-Sticker-emoji-2.0.3
# Directory '.\grouping-no-leak\group-1-no-leak\cute-pepe-snap-Sticker-emoji-2.0.3' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 121: Cutecam-Selfie-Camera-Editor-Expert-HD-Camera-1.4-------------------
# .\exif-java-no-leak\Cutecam-Selfie-Camera-Editor-Expert-HD-Camera-1.4
# Directory '.\grouping-no-leak\group-3-no-leak\Cutecam-Selfie-Camera-Editor-Expert-HD-Camera-1.4' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 122: CYCLECAM-1.1.9-------------------
# .\exif-java-no-leak\CYCLECAM-1.1.9
# Directory '.\grouping-no-leak\group-3-no-leak\CYCLECAM-1.1.9' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 123: Dark-Wallpapers-1.0.5-------------------
# .\exif-java-no-leak\Dark-Wallpapers-1.0.5
# Directory '.\grouping-no-leak\group-3-no-leak\Dark-Wallpapers-1.0.5' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 124: Darkify-Wallpaper-HD-4K-2023-1.0.6-------------------
# .\exif-java-no-leak\Darkify-Wallpaper-HD-4K-2023-1.0.6
# Directory '.\grouping-no-leak\group-3-no-leak\Darkify-Wallpaper-HD-4K-2023-1.0.6' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 125: DateCamera-Auto-timestamp-4.3.1-------------------
# .\exif-java-no-leak\DateCamera-Auto-timestamp-4.3.1
# Directory '.\grouping-no-leak\group-3-no-leak\DateCamera-Auto-timestamp-4.3.1' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 126: Depressed-Wallpaper-HD-1.1.0-------------------
# .\exif-java-no-leak\Depressed-Wallpaper-HD-1.1.0
# Directory '.\grouping-no-leak\group-1-no-leak\Depressed-Wallpaper-HD-1.1.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 127: Detroit-Become-Human-Wallpaper-1-------------------
# .\exif-java-no-leak\Detroit-Become-Human-Wallpaper-1
# Directory '.\grouping-no-leak\group-3-no-leak\Detroit-Become-Human-Wallpaper-1' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 128: Difuminator-1.1-------------------
# .\exif-java-no-leak\Difuminator-1.1
# Directory '.\grouping-no-leak\group-2-no-leak\Difuminator-1.1' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 129: Dinosaur-Wallpaper-4K-Ultra-HD-1.0.5-------------------
# .\exif-java-no-leak\Dinosaur-Wallpaper-4K-Ultra-HD-1.0.5
# Directory '.\grouping-no-leak\group-3-no-leak\Dinosaur-Wallpaper-4K-Ultra-HD-1.0.5' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 130: DM-Saver-for-Instagram-DM-1.1.0-------------------
# .\exif-java-no-leak\DM-Saver-for-Instagram-DM-1.1.0
# Directory '.\grouping-no-leak\group-3-no-leak\DM-Saver-for-Instagram-DM-1.1.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 131: Doggy-ears-dog-face-photo-editor-4.0-------------------
# .\exif-java-no-leak\Doggy-ears-dog-face-photo-editor-4.0
# Directory '.\grouping-no-leak\group-1-no-leak\Doggy-ears-dog-face-photo-editor-4.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 132: Doggy-Face-Camera-1.0-------------------
# .\exif-java-no-leak\Doggy-Face-Camera-1.0
# Directory '.\grouping-no-leak\group-1-no-leak\Doggy-Face-Camera-1.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 133: Dollify-Sticker-Photo-Editor-1.1-------------------
# .\exif-java-no-leak\Dollify-Sticker-Photo-Editor-1.1
# Directory '.\grouping-no-leak\group-1-no-leak\Dollify-Sticker-Photo-Editor-1.1' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 134: Download-Gram-1.4-------------------
# .\exif-java-no-leak\Download-Gram-1.4
# Directory '.\grouping-no-leak\group-1-no-leak\Download-Gram-1.4' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 135: Download-Profile-Picture-HD-9-------------------
# .\exif-java-no-leak\Download-Profile-Picture-HD-9
# Directory '.\grouping-no-leak\group-3-no-leak\Download-Profile-Picture-HD-9' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 136: Dragon-Ball-Z-Wallpapers-2.0-------------------
# .\exif-java-no-leak\Dragon-Ball-Z-Wallpapers-2.0
# Directory '.\grouping-no-leak\group-3-no-leak\Dragon-Ball-Z-Wallpapers-2.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 137: Dragon-Super-Saiyan-Photo-Editor-Camera-1.0-------------------
# .\exif-java-no-leak\Dragon-Super-Saiyan-Photo-Editor-Camera-1.0
# Directory '.\grouping-no-leak\group-3-no-leak\Dragon-Super-Saiyan-Photo-Editor-Camera-1.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 138: Dragones-Wallpaper-4K-Ultra-HD-1.0.2-------------------
# .\exif-java-no-leak\Dragones-Wallpaper-4K-Ultra-HD-1.0.2
# Directory '.\grouping-no-leak\group-3-no-leak\Dragones-Wallpaper-4K-Ultra-HD-1.0.2' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 139: Dragons-Live-Wallpapers-HD-1.7-------------------
# .\exif-java-no-leak\Dragons-Live-Wallpapers-HD-1.7
# Directory '.\grouping-no-leak\group-1-no-leak\Dragons-Live-Wallpapers-HD-1.7' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 140: Driving-Licence-Maker-Generator-1.1-------------------
# .\exif-java-no-leak\Driving-Licence-Maker-Generator-1.1
# Directory '.\grouping-no-leak\group-3-no-leak\Driving-Licence-Maker-Generator-1.1' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 141: DroneView-Mobile-2.14-------------------
# .\exif-java-no-leak\DroneView-Mobile-2.14
# Directory '.\grouping-no-leak\group-3-no-leak\DroneView-Mobile-2.14' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 142: Drop-Shadow-For-Instagram-Fi-1.0.2-------------------
# .\exif-java-no-leak\Drop-Shadow-For-Instagram-Fi-1.0.2
# Directory '.\grouping-no-leak\group-3-no-leak\Drop-Shadow-For-Instagram-Fi-1.0.2' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 143: DSLR-Camera-Blur-Photo-1.2-------------------
# .\exif-java-no-leak\DSLR-Camera-Blur-Photo-1.2
# Directory '.\grouping-no-leak\group-1-no-leak\DSLR-Camera-Blur-Photo-1.2' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 144: DSLR-Camera-Photo-Editor-2.0.0-------------------
# .\exif-java-no-leak\DSLR-Camera-Photo-Editor-2.0.0
# Directory '.\grouping-no-leak\group-1-no-leak\DSLR-Camera-Photo-Editor-2.0.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 145: DSLR-HD-Camera-1.3.3-------------------
# .\exif-java-no-leak\DSLR-HD-Camera-1.3.3
# Directory '.\grouping-no-leak\group-3-no-leak\DSLR-HD-Camera-1.3.3' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 146: Dslr-Photography-Pose-2.0-------------------
# .\exif-java-no-leak\Dslr-Photography-Pose-2.0
# Directory '.\grouping-no-leak\group-1-no-leak\Dslr-Photography-Pose-2.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 147: DSLR-Shutter-Count-PREMIUM-1.1-------------------
# .\exif-java-no-leak\DSLR-Shutter-Count-PREMIUM-1.1
# Directory '.\grouping-no-leak\group-3-no-leak\DSLR-Shutter-Count-PREMIUM-1.1' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 148: DU-GIF-Maker-GIF-Maker-Video-to-GIF-GIF-Editor-1.2.2.2-------------------
# .\exif-java-no-leak\DU-GIF-Maker-GIF-Maker-Video-to-GIF-GIF-Editor-1.2.2.2
# Directory '.\grouping-no-leak\group-1-no-leak\DU-GIF-Maker-GIF-Maker-Video-to-GIF-GIF-Editor-1.2.2.2' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 149: Dual-Camera-8.0-------------------
# .\exif-java-no-leak\Dual-Camera-8.0
# Directory '.\grouping-no-leak\group-1-no-leak\Dual-Camera-8.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 150: Dual-Photo-Mixer-Photo-joint-1.24-------------------
# .\exif-java-no-leak\Dual-Photo-Mixer-Photo-joint-1.24
# Directory '.\grouping-no-leak\group-3-no-leak\Dual-Photo-Mixer-Photo-joint-1.24' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 151: Easy-Photo-Eraser-3.0-------------------
# .\exif-java-no-leak\Easy-Photo-Eraser-3.0
# Directory '.\grouping-no-leak\group-3-no-leak\Easy-Photo-Eraser-3.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 152: EasyN-P2-7.5-------------------
# .\exif-java-no-leak\EasyN-P2-7.5
# Directory '.\grouping-no-leak\group-3-no-leak\EasyN-P2-7.5' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 153: Editor-De-Foto-Efeito-Snapchat-1.9.2-------------------
# .\exif-java-no-leak\Editor-De-Foto-Efeito-Snapchat-1.9.2
# Directory '.\grouping-no-leak\group-3-no-leak\Editor-De-Foto-Efeito-Snapchat-1.9.2' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 154: Editor-de-Fotos-1.6-------------------
# .\exif-java-no-leak\Editor-de-Fotos-1.6
# Directory '.\grouping-no-leak\group-1-no-leak\Editor-de-Fotos-1.6' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 155: Editor-Photo-BC12-0.0-------------------
# .\exif-java-no-leak\Editor-Photo-BC12-0.0
# Directory '.\grouping-no-leak\group-3-no-leak\Editor-Photo-BC12-0.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 156: Effects-Video-Filters-Camera-2.1.70-------------------
# .\exif-java-no-leak\Effects-Video-Filters-Camera-2.1.70
# Directory '.\grouping-no-leak\group-3-no-leak\Effects-Video-Filters-Camera-2.1.70' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 157: Eid-Mubarak-Photo-Frame-2023-SM-v13-------------------
# .\exif-java-no-leak\Eid-Mubarak-Photo-Frame-2023-SM-v13
# Directory '.\grouping-no-leak\group-2-no-leak\Eid-Mubarak-Photo-Frame-2023-SM-v13' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 158: Emoji-Background-Photo-Editor-1.8-------------------
# .\exif-java-no-leak\Emoji-Background-Photo-Editor-1.8
# Directory '.\grouping-no-leak\group-1-no-leak\Emoji-Background-Photo-Editor-1.8' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 159: Emoji-Camera-3.0-------------------
# .\exif-java-no-leak\Emoji-Camera-3.0
# Directory '.\grouping-no-leak\group-3-no-leak\Emoji-Camera-3.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 160: Emoji-Creator-1.0-------------------
# .\exif-java-no-leak\Emoji-Creator-1.0
# Directory '.\grouping-no-leak\group-3-no-leak\Emoji-Creator-1.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 161: Enlight-Pixaloop-1.0-------------------
# .\exif-java-no-leak\Enlight-Pixaloop-1.0
# Directory '.\grouping-no-leak\group-3-no-leak\Enlight-Pixaloop-1.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 162: enlight-pixaloop-App-on-android-Advice-1.0-------------------
# .\exif-java-no-leak\enlight-pixaloop-App-on-android-Advice-1.0
# Directory '.\grouping-no-leak\group-3-no-leak\enlight-pixaloop-App-on-android-Advice-1.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 163: Eren-Jaeger-Titan-Wallpaper-HD-1.0-------------------
# .\exif-java-no-leak\Eren-Jaeger-Titan-Wallpaper-HD-1.0
# Directory '.\grouping-no-leak\group-3-no-leak\Eren-Jaeger-Titan-Wallpaper-HD-1.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 164: Essentional-1.0-------------------
# .\exif-java-no-leak\Essentional-1.0
# Directory '.\grouping-no-leak\group-3-no-leak\Essentional-1.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 165: Eye-Blinker-Free-1.05-------------------
# .\exif-java-no-leak\Eye-Blinker-Free-1.05
# Directory '.\grouping-no-leak\group-3-no-leak\Eye-Blinker-Free-1.05' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 166: Eye-Color-Changer-3.4.8-------------------
# .\exif-java-no-leak\Eye-Color-Changer-3.4.8
# Directory '.\grouping-no-leak\group-3-no-leak\Eye-Color-Changer-3.4.8' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 167: Eyebrow-Shape-Changer-and-Edit-10.0-------------------
# .\exif-java-no-leak\Eyebrow-Shape-Changer-and-Edit-10.0
# Directory '.\grouping-no-leak\group-1-no-leak\Eyebrow-Shape-Changer-and-Edit-10.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 168: Face-Funny-NEW-2017-1.0-------------------
# .\exif-java-no-leak\Face-Funny-NEW-2017-1.0
# Directory '.\grouping-no-leak\group-3-no-leak\Face-Funny-NEW-2017-1.0' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 169: Face-Morph-1.4.1-------------------
# .\exif-java-no-leak\Face-Morph-1.4.1
# Directory '.\grouping-no-leak\group-3-no-leak\Face-Morph-1.4.1' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 170: Fake-Abs-Photo-Editor-Six-Pack-Camera-1.2-------------------
# .\exif-java-no-leak\Fake-Abs-Photo-Editor-Six-Pack-Camera-1.2
# Directory '.\grouping-no-leak\group-1-no-leak\Fake-Abs-Photo-Editor-Six-Pack-Camera-1.2' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 171: Fake-ID-Card-Maker-Card-Making-App-1.1-------------------
# .\exif-java-no-leak\Fake-ID-Card-Maker-Card-Making-App-1.1
# Directory '.\grouping-no-leak\group-3-no-leak\Fake-ID-Card-Maker-Card-Making-App-1.1' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 172: Fake-Newspaper-Maker-Creator-1.2.6-------------------
# .\exif-java-no-leak\Fake-Newspaper-Maker-Creator-1.2.6
# Directory '.\grouping-no-leak\group-3-no-leak\Fake-Newspaper-Maker-Creator-1.2.6' already exists.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# ...
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 583: Twin-Camera-Selfie-Clone-Yours-1.0-------------------
# .\exif-java-no-leak\Twin-Camera-Selfie-Clone-Yours-1.0
# Directory '.\exif-java-no-leak\Twin-Camera-Selfie-Clone-Yours-1.0' copied to '.\grouping-no-leak\group-3-no-leak\Twin-Camera-Selfie-Clone-Yours-1.0' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 584: Typorama-Text-on-Photo-Editor-3.0-------------------
# .\exif-java-no-leak\Typorama-Text-on-Photo-Editor-3.0
# Directory '.\exif-java-no-leak\Typorama-Text-on-Photo-Editor-3.0' copied to '.\grouping-no-leak\group-1-no-leak\Typorama-Text-on-Photo-Editor-3.0' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 585: Uchiha-Sharingan-Madara-Eyes-1.0-------------------
# .\exif-java-no-leak\Uchiha-Sharingan-Madara-Eyes-1.0
# Directory '.\exif-java-no-leak\Uchiha-Sharingan-Madara-Eyes-1.0' copied to '.\grouping-no-leak\group-1-no-leak\Uchiha-Sharingan-Madara-Eyes-1.0' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 586: Ugadi-photo-frames-1.12-------------------
# .\exif-java-no-leak\Ugadi-photo-frames-1.12
# Directory '.\exif-java-no-leak\Ugadi-photo-frames-1.12' copied to '.\grouping-no-leak\group-3-no-leak\Ugadi-photo-frames-1.12' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 587: Ugandan-Knuckles-Wallpapers-HD-1.0.0-------------------
# .\exif-java-no-leak\Ugandan-Knuckles-Wallpapers-HD-1.0.0
# Directory '.\exif-java-no-leak\Ugandan-Knuckles-Wallpapers-HD-1.0.0' copied to '.\grouping-no-leak\group-3-no-leak\Ugandan-Knuckles-Wallpapers-HD-1.0.0' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 588: Ugly-Camera-Funny-Selfies-3.4-------------------
# .\exif-java-no-leak\Ugly-Camera-Funny-Selfies-3.4
# Directory '.\exif-java-no-leak\Ugly-Camera-Funny-Selfies-3.4' copied to '.\grouping-no-leak\group-1-no-leak\Ugly-Camera-Funny-Selfies-3.4' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 589: Ultra-Zoom-Telescope-HD-Camera-2.2.2-------------------
# .\exif-java-no-leak\Ultra-Zoom-Telescope-HD-Camera-2.2.2
# Directory '.\exif-java-no-leak\Ultra-Zoom-Telescope-HD-Camera-2.2.2' copied to '.\grouping-no-leak\group-3-no-leak\Ultra-Zoom-Telescope-HD-Camera-2.2.2' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 590: Under-Water-Coral-Theme-Magic-Sea-Wallpaper-HD-1.0.0-------------------
# .\exif-java-no-leak\Under-Water-Coral-Theme-Magic-Sea-Wallpaper-HD-1.0.0
# Directory '.\exif-java-no-leak\Under-Water-Coral-Theme-Magic-Sea-Wallpaper-HD-1.0.0' copied to '.\grouping-no-leak\group-3-no-leak\Under-Water-Coral-Theme-Magic-Sea-Wallpaper-HD-1.0.0' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 591: Unicorn-Photo-Editor-Kawaii-Stickers-1.4-------------------
# .\exif-java-no-leak\Unicorn-Photo-Editor-Kawaii-Stickers-1.4
# Directory '.\exif-java-no-leak\Unicorn-Photo-Editor-Kawaii-Stickers-1.4' copied to '.\grouping-no-leak\group-1-no-leak\Unicorn-Photo-Editor-Kawaii-Stickers-1.4' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 592: Unicorn-Photo-Stickers-Cute-Photo-Editor-for-Girl-1.8-------------------
# .\exif-java-no-leak\Unicorn-Photo-Stickers-Cute-Photo-Editor-for-Girl-1.8
# Directory '.\exif-java-no-leak\Unicorn-Photo-Stickers-Cute-Photo-Editor-for-Girl-1.8' copied to '.\grouping-no-leak\group-1-no-leak\Unicorn-Photo-Stickers-Cute-Photo-Editor-for-Girl-1.8' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 593: Unicorn-Tumblr-Wallpaper-1.0-------------------
# .\exif-java-no-leak\Unicorn-Tumblr-Wallpaper-1.0
# Directory '.\exif-java-no-leak\Unicorn-Tumblr-Wallpaper-1.0' copied to '.\grouping-no-leak\group-3-no-leak\Unicorn-Tumblr-Wallpaper-1.0' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 594: Unicorn-Yourself-Unicorn-Filters-1.0-------------------
# .\exif-java-no-leak\Unicorn-Yourself-Unicorn-Filters-1.0
# Directory '.\exif-java-no-leak\Unicorn-Yourself-Unicorn-Filters-1.0' copied to '.\grouping-no-leak\group-1-no-leak\Unicorn-Yourself-Unicorn-Filters-1.0' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 595: Upload-to-Kiosk-1.3.1-------------------
# .\exif-java-no-leak\Upload-to-Kiosk-1.3.1
# Directory '.\exif-java-no-leak\Upload-to-Kiosk-1.3.1' copied to '.\grouping-no-leak\group-3-no-leak\Upload-to-Kiosk-1.3.1' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 596: Vampire-Camera-Photo-Editor-2.1-------------------
# .\exif-java-no-leak\Vampire-Camera-Photo-Editor-2.1
# Directory '.\exif-java-no-leak\Vampire-Camera-Photo-Editor-2.1' copied to '.\grouping-no-leak\group-1-no-leak\Vampire-Camera-Photo-Editor-2.1' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 597: Vampire-Look-Photo-Editor-1.2-------------------
# .\exif-java-no-leak\Vampire-Look-Photo-Editor-1.2
# Directory '.\exif-java-no-leak\Vampire-Look-Photo-Editor-1.2' copied to '.\grouping-no-leak\group-1-no-leak\Vampire-Look-Photo-Editor-1.2' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 598: Video-Boys-3.4-------------------
# .\exif-java-no-leak\Video-Boys-3.4
# Directory '.\exif-java-no-leak\Video-Boys-3.4' copied to '.\grouping-no-leak\group-3-no-leak\Video-Boys-3.4' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 599: Village-Photo-Frames-1.5-------------------
# .\exif-java-no-leak\Village-Photo-Frames-1.5
# Directory '.\exif-java-no-leak\Village-Photo-Frames-1.5' copied to '.\grouping-no-leak\group-3-no-leak\Village-Photo-Frames-1.5' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 600: Visiting-Card-Maker-1.4-------------------
# .\exif-java-no-leak\Visiting-Card-Maker-1.4
# Directory '.\exif-java-no-leak\Visiting-Card-Maker-1.4' copied to '.\grouping-no-leak\group-2-no-leak\Visiting-Card-Maker-1.4' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 601: Visual-Watermark-Photos-PDF-2.6-------------------
# .\exif-java-no-leak\Visual-Watermark-Photos-PDF-2.6
# Directory '.\exif-java-no-leak\Visual-Watermark-Photos-PDF-2.6' copied to '.\grouping-no-leak\group-2-no-leak\Visual-Watermark-Photos-PDF-2.6' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 602: Vivid-Photo-1.5-------------------
# .\exif-java-no-leak\Vivid-Photo-1.5
# Directory '.\exif-java-no-leak\Vivid-Photo-1.5' copied to '.\grouping-no-leak\group-3-no-leak\Vivid-Photo-1.5' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 603: Wall-E-Paper-1.0-------------------
# .\exif-java-no-leak\Wall-E-Paper-1.0
# Directory '.\exif-java-no-leak\Wall-E-Paper-1.0' copied to '.\grouping-no-leak\group-3-no-leak\Wall-E-Paper-1.0' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 604: Wallpaper-Gitar-Akustik-Keren-2.1.3-------------------
# .\exif-java-no-leak\Wallpaper-Gitar-Akustik-Keren-2.1.3
# Directory '.\exif-java-no-leak\Wallpaper-Gitar-Akustik-Keren-2.1.3' copied to '.\grouping-no-leak\group-1-no-leak\Wallpaper-Gitar-Akustik-Keren-2.1.3' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 605: Wallpapers-for-Huawei-1.0.0-------------------
# .\exif-java-no-leak\Wallpapers-for-Huawei-1.0.0
# Directory '.\exif-java-no-leak\Wallpapers-for-Huawei-1.0.0' copied to '.\grouping-no-leak\group-3-no-leak\Wallpapers-for-Huawei-1.0.0' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 606: WataameCamera-1.17-------------------
# .\exif-java-no-leak\WataameCamera-1.17
# Directory '.\exif-java-no-leak\WataameCamera-1.17' copied to '.\grouping-no-leak\group-3-no-leak\WataameCamera-1.17' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 607: Watermarkly-Photos-PDF-2.4-------------------
# .\exif-java-no-leak\Watermarkly-Photos-PDF-2.4
# Directory '.\exif-java-no-leak\Watermarkly-Photos-PDF-2.4' copied to '.\grouping-no-leak\group-3-no-leak\Watermarkly-Photos-PDF-2.4' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 608: WatermarkRemover.io-1.0.8-------------------
# .\exif-java-no-leak\WatermarkRemover.io-1.0.8
# Directory '.\exif-java-no-leak\WatermarkRemover.io-1.0.8' copied to '.\grouping-no-leak\group-3-no-leak\WatermarkRemover.io-1.0.8' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 609: Webp-Image-Converter-Jpg-to-2.0.2-------------------
# .\exif-java-no-leak\Webp-Image-Converter-Jpg-to-2.0.2
# Directory '.\exif-java-no-leak\Webp-Image-Converter-Jpg-to-2.0.2' copied to '.\grouping-no-leak\group-2-no-leak\Webp-Image-Converter-Jpg-to-2.0.2' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 610: Whitagram-1.0-------------------
# .\exif-java-no-leak\Whitagram-1.0
# Directory '.\exif-java-no-leak\Whitagram-1.0' copied to '.\grouping-no-leak\group-3-no-leak\Whitagram-1.0' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 611: Whitagram-for-Android-App-Advice-1.0-------------------
# .\exif-java-no-leak\Whitagram-for-Android-App-Advice-1.0
# Directory '.\exif-java-no-leak\Whitagram-for-Android-App-Advice-1.0' copied to '.\grouping-no-leak\group-3-no-leak\Whitagram-for-Android-App-Advice-1.0' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 612: White-Border-Square-Fit-Photo-3.21.3-------------------
# .\exif-java-no-leak\White-Border-Square-Fit-Photo-3.21.3
# Directory '.\exif-java-no-leak\White-Border-Square-Fit-Photo-3.21.3' copied to '.\grouping-no-leak\group-3-no-leak\White-Border-Square-Fit-Photo-3.21.3' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 613: Widget-smith-1.0-------------------
# .\exif-java-no-leak\Widget-smith-1.0
# Directory '.\exif-java-no-leak\Widget-smith-1.0' copied to '.\grouping-no-leak\group-2-no-leak\Widget-smith-1.0' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 614: Wish-U-Happy-Birthday-Photo-Editor-with-Name-1.0-------------------
# .\exif-java-no-leak\Wish-U-Happy-Birthday-Photo-Editor-with-Name-1.0
# Directory '.\exif-java-no-leak\Wish-U-Happy-Birthday-Photo-Editor-with-Name-1.0' copied to '.\grouping-no-leak\group-1-no-leak\Wish-U-Happy-Birthday-Photo-Editor-with-Name-1.0' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 615: Wizard-Photo-Editor-2.18-------------------
# .\exif-java-no-leak\Wizard-Photo-Editor-2.18
# Directory '.\exif-java-no-leak\Wizard-Photo-Editor-2.18' copied to '.\grouping-no-leak\group-3-no-leak\Wizard-Photo-Editor-2.18' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 616: Women-Anarkali-Dress-PhotoSuit-1.7-------------------
# .\exif-java-no-leak\Women-Anarkali-Dress-PhotoSuit-1.7
# Directory '.\exif-java-no-leak\Women-Anarkali-Dress-PhotoSuit-1.7' copied to '.\grouping-no-leak\group-3-no-leak\Women-Anarkali-Dress-PhotoSuit-1.7' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 617: Women-Bike-Photo-Montage-1.0.7-------------------
# .\exif-java-no-leak\Women-Bike-Photo-Montage-1.0.7
# Directory '.\exif-java-no-leak\Women-Bike-Photo-Montage-1.0.7' copied to '.\grouping-no-leak\group-3-no-leak\Women-Bike-Photo-Montage-1.0.7' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 618: Women-Girls-Anarkali-Frocks-1.4-------------------
# .\exif-java-no-leak\Women-Girls-Anarkali-Frocks-1.4
# Directory '.\exif-java-no-leak\Women-Girls-Anarkali-Frocks-1.4' copied to '.\grouping-no-leak\group-3-no-leak\Women-Girls-Anarkali-Frocks-1.4' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 619: Women-Jeans-Fashion-Tops-1.5-------------------
# .\exif-java-no-leak\Women-Jeans-Fashion-Tops-1.5
# Directory '.\exif-java-no-leak\Women-Jeans-Fashion-Tops-1.5' copied to '.\grouping-no-leak\group-2-no-leak\Women-Jeans-Fashion-Tops-1.5' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 620: Women-Long-Skirts-Dresses-1.3-------------------
# .\exif-java-no-leak\Women-Long-Skirts-Dresses-1.3
# Directory '.\exif-java-no-leak\Women-Long-Skirts-Dresses-1.3' copied to '.\grouping-no-leak\group-3-no-leak\Women-Long-Skirts-Dresses-1.3' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 621: Women-Pattu-Saree-Photo-Maker-1.7-------------------
# .\exif-java-no-leak\Women-Pattu-Saree-Photo-Maker-1.7
# Directory '.\exif-java-no-leak\Women-Pattu-Saree-Photo-Maker-1.7' copied to '.\grouping-no-leak\group-2-no-leak\Women-Pattu-Saree-Photo-Maker-1.7' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 622: Women-Saree-Photo-Maker-1.0.6-------------------
# .\exif-java-no-leak\Women-Saree-Photo-Maker-1.0.6
# Directory '.\exif-java-no-leak\Women-Saree-Photo-Maker-1.0.6' copied to '.\grouping-no-leak\group-3-no-leak\Women-Saree-Photo-Maker-1.0.6' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 623: Women-Shirt-Photo-Editor-2.5-------------------
# .\exif-java-no-leak\Women-Shirt-Photo-Editor-2.5
# Directory '.\exif-java-no-leak\Women-Shirt-Photo-Editor-2.5' copied to '.\grouping-no-leak\group-2-no-leak\Women-Shirt-Photo-Editor-2.5' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 624: WTMP-6.3.4-------------------
# .\exif-java-no-leak\WTMP-6.3.4
# Directory '.\exif-java-no-leak\WTMP-6.3.4' copied to '.\grouping-no-leak\group-3-no-leak\WTMP-6.3.4' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 625: WWE-Wallpaper-HD-1.0-------------------
# .\exif-java-no-leak\WWE-Wallpaper-HD-1.0
# Directory '.\exif-java-no-leak\WWE-Wallpaper-HD-1.0' copied to '.\grouping-no-leak\group-1-no-leak\WWE-Wallpaper-HD-1.0' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 626: X-Cam-1.0.24-------------------
# .\exif-java-no-leak\X-Cam-1.0.24
# Directory '.\exif-java-no-leak\X-Cam-1.0.24' copied to '.\grouping-no-leak\group-3-no-leak\X-Cam-1.0.24' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 627: XDV-1.9.53-------------------
# .\exif-java-no-leak\XDV-1.9.53
# Directory '.\exif-java-no-leak\XDV-1.9.53' copied to '.\grouping-no-leak\group-1-no-leak\XDV-1.9.53' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 628: YCamera-1.37-------------------
# .\exif-java-no-leak\YCamera-1.37
# Directory '.\exif-java-no-leak\YCamera-1.37' copied to '.\grouping-no-leak\group-3-no-leak\YCamera-1.37' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 629: YiCam-1.0-------------------
# .\exif-java-no-leak\YiCam-1.0
# Directory '.\exif-java-no-leak\YiCam-1.0' copied to '.\grouping-no-leak\group-3-no-leak\YiCam-1.0' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
# -------------------Loop 630: Your-Cam-1.0-------------------
# .\exif-java-no-leak\Your-Cam-1.0
# Directory '.\exif-java-no-leak\Your-Cam-1.0' copied to '.\grouping-no-leak\group-3-no-leak\Your-Cam-1.0' successfully.
# CSV file 'no_leak_apk_low_size.csv' updated successfully.
